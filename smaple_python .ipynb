# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker
from sklearn import preprocessing
# %matplotlib inline
# Out:
# In /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
#ADDING OF DATA SETS

# %%
# !wget -O loan_train.csv https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_train.csv
# Out:
# --2021-07-07 09:26:32--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_train.csv
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23101 (23K) [text/csv]
# Saving to: ‘loan_train.csv’
#
# loan_train.csv      100%[===================>]  22.56K  --.-KB/s    in 0.07s
#
# 2021-07-07 09:26:33 (305 KB/s) - ‘loan_train.csv’ saved [23101/23101]

# %%
df = pd.read_csv('loan_train.csv')
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30       9/8/2016
# 1           2             2     PAIDOFF       1000     30       9/8/2016
# 2           3             3     PAIDOFF       1000     15       9/8/2016
# 3           4             4     PAIDOFF       1000     30       9/9/2016
# 4           6             6     PAIDOFF       1000     30       9/9/2016
#
#     due_date  age             education  Gender
# 0  10/7/2016   45  High School or Below    male
# 1  10/7/2016   33              Bechalor  female
# 2  9/22/2016   27               college    male
# 3  10/8/2016   28               college  female
# 4  10/8/2016   29               college    male

# %%
df['due_date'] = pd.to_datetime(df['due_date'])
df['effective_date'] = pd.to_datetime(df['effective_date'])
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender
# 0 2016-10-07   45  High School or Below    male
# 1 2016-10-07   33              Bechalor  female
# 2 2016-09-22   27               college    male
# 3 2016-10-08   28               college  female
# 4 2016-10-08   29               college    male

# %%
#Data visualization and pre-processing
df['loan_status'].value_counts()
# Out:
# PAIDOFF       260
# COLLECTION     86
# Name: loan_status, dtype: int64

# %%
# !conda install -c anaconda seaborn -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::mkl-service==2.3.0=py37he8ac12f_0
#   - defaults/linux-64::webencodings==0.5.1=py37_1
#   - defaults/noarch::pycparser==2.20=py_2
#   - defaults/linux-64::mkl_random==1.1.1=py37h0573a6f_0
#   - defaults/linux-64::pyqt==5.9.2=py37h05f1152_2
#   - defaults/linux-64::sip==4.19.8=py37hf484d3e_0
#   - defaults/linux-64::retrying==1.3.3=py37_2
#   - defaults/linux-64::pyodbc==4.0.30=py37he6710b0_0
#   - defaults/noarch::imageio==2.9.0=pyhd3eb1b0_0
#   - defaults/noarch::pyasn1-modules==0.2.8=py_0
#   - defaults/linux-64::cycler==0.10.0=py37_0
#   - defaults/noarch::send2trash==1.5.0=pyhd3eb1b0_1
#   - defaults/linux-64::keyring==18.0.0=py37_0
#   - defaults/noarch::pyparsing==2.4.7=pyhd3eb1b0_0
#   - defaults/linux-64::entrypoints==0.3=py37_0
#   - defaults/linux-64::future==0.18.2=py37_1
#   - defaults/linux-64::libuuid==1.0.3=h1bed415_2
#   - defaults/linux-64::qt==5.9.7=h5867ecd_1
#   - defaults/linux-64::pytables==3.6.1=py37h71ec239_0
#   - defaults/linux-64::snappy==1.1.8=he6710b0_0
#   - defaults/linux-64::lxml==4.6.3=py37h9120a33_0
#   - defaults/linux-64::hdf5==1.10.4=hb1b8bf9_0
#   - defaults/linux-64::pluggy==0.13.1=py37h06a4308_0
#   - defaults/linux-64::libwebp-base==1.2.0=h27cfd23_0
#   - defaults/linux-64::krb5==1.17.1=h173b8e3_0
#   - defaults/noarch::oauthlib==3.1.0=py_0
#   - defaults/linux-64::libpng==1.6.37=hbc83047_0
#   - defaults/noarch::google-pasta==0.2.0=py_0
#   - defaults/linux-64::certifi==2021.5.30=py37h06a4308_0
#   - defaults/linux-64::libpq==12.2=h20c2e04_0
#   - defaults/noarch::html5lib==1.1=py_0
#   - defaults/linux-64::libtiff==4.2.0=h85742a9_0
#   - defaults/linux-64::tk==8.6.10=hbc83047_0
#   - defaults/linux-64::pymssql==2.1.5=py37h7b6447c_0
#   - defaults/noarch::pyshp==2.1.0=py_0
#   - defaults/linux-64::pyjwt==1.7.1=py37_0
#   - defaults/linux-64::jpeg==9b=h024ee3a_2
#   - defaults/linux-64::bzip2==1.0.8=h7b6447c_0
#   - defaults/noarch::python-dateutil==2.8.1=pyhd3eb1b0_0
#   - defaults/linux-64::mistune==0.8.4=py37h14c3975_1001
#   - defaults/linux-64::blinker==1.4=py37h06a4308_0
#   - defaults/noarch::ipython_genutils==0.2.0=pyhd3eb1b0_1
#   - defaults/linux-64::cryptography==3.4.7=py37hd23ed53_0
#   - defaults/linux-64::lzo==2.10=h7b6447c_2
#   - defaults/linux-64::h5py==2.10.0=py37h7918eee_0
#   - defaults/noarch::jsonschema==3.2.0=py_2
#   - defaults/linux-64::pysocks==1.7.1=py37_1
#   - defaults/linux-64::wrapt==1.12.1=py37h7b6447c_1
#   - defaults/linux-64::ncurses==6.2=he6710b0_1
#   - defaults/linux-64::pywavelets==1.1.1=py37h7b6447c_2
#   - esri/linux-64::arcgis==1.6.0=py37h39e3cac_1
#   - defaults/noarch::jupyterlab==2.2.6=pyhd3eb1b0_1
#   - defaults/noarch::requests-oauthlib==1.3.0=py_0
#   - defaults/linux-64::yaml==0.2.5=h7b6447c_0
#   - defaults/linux-64::libxcb==1.14=h7b6447c_0
#   - defaults/linux-64::openssl==1.1.1k=h27cfd23_0
#   - defaults/linux-64::icu==58.2=he6710b0_3
#   - defaults/linux-64::patsy==0.5.1=py37_0
#   - defaults/linux-64::brotlipy==0.7.0=py37h27cfd23_1003
#   - defaults/linux-64::libxslt==1.1.34=hc22bd24_0
#   - defaults/noarch::keras-applications==1.0.8=py_1
#   - defaults/linux-64::olefile==0.46=py37_0
#   - defaults/noarch::pyasn1==0.4.8=py_0
#   - defaults/linux-64::widgetsnbextension==3.5.1=py37_0
#   - defaults/noarch::pexpect==4.8.0=pyhd3eb1b0_3
#   - defaults/linux-64::zlib==1.2.11=h7b6447c_3
#   - defaults/noarch::threadpoolctl==2.1.0=pyh5ca1d4c_0
#   - defaults/linux-64::libffi==3.3=he6710b0_2
#   - defaults/linux-64::fastcache==1.1.0=py37h7b6447c_0
#   - defaults/linux-64::pyyaml==5.4.1=py37h27cfd23_1
#   - defaults/linux-64::freetds==1.00.97=h52ef933_0
#   - defaults/noarch::backcall==0.2.0=pyhd3eb1b0_0
#   - defaults/linux-64::xz==5.2.5=h7b6447c_0
#   - defaults/noarch::werkzeug==1.0.1=pyhd3eb1b0_0
#   - defaults/linux-64::chardet==3.0.4=py37h06a4308_1003
#   - defaults/linux-64::async-timeout==3.0.1=py37h06a4308_0
#   - defaults/noarch::pickleshare==0.7.5=pyhd3eb1b0_1003
#   - defaults/linux-64::libsodium==1.0.18=h7b6447c_0
#   - defaults/linux-64::termcolor==1.1.0=py37h06a4308_1
#   - defaults/linux-64::yarl==1.6.3=py37h27cfd23_0
#   - defaults/noarch::traitlets==5.0.5=pyhd3eb1b0_0
#   - defaults/linux-64::pcre==8.45=h295c915_0
#   - defaults/linux-64::mpmath==1.2.1=py37h06a4308_0
#   - defaults/linux-64::blosc==1.21.0=h8c45485_0
#   - defaults/linux-64::fontconfig==2.13.1=h6c09931_0
#   - defaults/noarch::joblib==1.0.1=pyhd3eb1b0_0
#   - defaults/noarch::iniconfig==1.1.1=pyhd3eb1b0_0
#   - defaults/linux-64::libgcc-ng==9.3.0=h5101ec6_17
#   - defaults/noarch::tensorflow-estimator==2.5.0=pyh7b7c402_0
#   - defaults/linux-64::astropy==4.2.1=py37h27cfd23_1
#   - defaults/noarch::bleach==3.3.0=pyhd3eb1b0_0
#   - defaults/noarch::xlsxwriter==1.4.3=pyhd3eb1b0_0
#   - defaults/noarch::boto3==1.17.101=pyhd3eb1b0_0
#   - defaults/linux-64::markupsafe==2.0.1=py37h27cfd23_0
#   - defaults/linux-64::scikit-image==0.18.1=py37ha9443f7_0
#   - defaults/linux-64::multidict==5.1.0=py37h27cfd23_2
#   - defaults/linux-64::sympy==1.8=py37h06a4308_0
#   - defaults/linux-64::lcms2==2.12=h3be6417_0
#   - defaults/linux-64::locket==0.2.1=py37h06a4308_1
#   - defaults/linux-64::sqlalchemy==1.4.19=py37h7f8727e_0
#   - defaults/noarch::ibm-wsrt-py37main-keep==0.0.0=2527
#   - defaults/linux-64::regex==2021.4.4=py37h27cfd23_0
#   - defaults/noarch::nltk==3.6.2=pyhd3eb1b0_0
#   - defaults/noarch::zipp==3.4.1=pyhd3eb1b0_0
#   - defaults/linux-64::psycopg2==2.8.6=py37h3c74f83_1
#   - defaults/linux-64::gst-plugins-base==1.14.0=h8213a91_2
#   - defaults/linux-64::c-ares==1.17.1=h27cfd23_0
#   - defaults/noarch::wheel==0.36.2=pyhd3eb1b0_0
#   - defaults/linux-64::aiohttp==3.7.4=py37h27cfd23_1
#   - defaults/noarch::plotly==4.14.3=pyhd3eb1b0_0
#   - defaults/linux-64::jedi==0.17.0=py37_0
#   - defaults/linux-64::statsmodels==0.12.2=py37h27cfd23_0
#   - defaults/noarch::pytz==2021.1=pyhd3eb1b0_0
#   - defaults/linux-64::cffi==1.14.5=py37h261ae71_0
#   - defaults/linux-64::libedit==3.1.20210216=h27cfd23_1
#   - defaults/noarch::fsspec==2021.6.0=pyhd3eb1b0_0
#   - defaults/noarch::jupyterlab_widgets==1.0.0=pyhd3eb1b0_1
#   - defaults/linux-64::dbus==1.13.18=hb2f20db_0
#   - defaults/noarch::jinja2==3.0.1=pyhd3eb1b0_0
#   - defaults/noarch::rsa==4.7.2=pyhd3eb1b0_1
#   - defaults/noarch::toml==0.10.2=pyhd3eb1b0_0
#   - defaults/noarch::py==1.10.0=pyhd3eb1b0_0
#   - defaults/linux-64::zstd==1.4.9=haebb681_0
#   - defaults/linux-64::importlib-metadata==3.10.0=py37h06a4308_0
#   - defaults/linux-64::libprotobuf==3.14.0=h8c45485_0
#   - defaults/linux-64::matplotlib==3.3.4=py37h06a4308_0
#   - defaults/noarch::prometheus_client==0.11.0=pyhd3eb1b0_0
#   - defaults/linux-64::python==3.7.10=h12debd9_4
#   - defaults/linux-64::biopython==1.78=py37h7b6447c_0
#   - defaults/linux-64::freetype==2.10.4=h5ab3b9f_0
#   - defaults/noarch::keras-preprocessing==1.1.2=pyhd3eb1b0_0
#   - defaults/noarch::nbformat==5.1.3=pyhd3eb1b0_0
#   - defaults/linux-64::pip==21.1.3=py37h06a4308_0
#   - defaults/linux-64::ninja==1.10.2=hff7bd54_1
#   - defaults/linux-64::mpfr==4.0.2=hb69a4c5_1
#   - defaults/linux-64::protobuf==3.14.0=py37h2531618_1
#   - defaults/noarch::jupyter_client==6.1.12=pyhd3eb1b0_0
#   - defaults/linux-64::pyerfa==2.0.0=py37h27cfd23_0
#   - defaults/linux-64::terminado==0.9.4=py37h06a4308_0
#   - defaults/noarch::jupyterlab_pygments==0.1.2=py_0
#   - defaults/linux-64::coverage==5.5=py37h27cfd23_2
#   - defaults/linux-64::gmpy2==2.0.8=py37h10f8cd9_2
#   - defaults/linux-64::astor==0.8.1=py37h06a4308_0
#   - defaults/linux-64::ipython==7.22.0=py37hb070fc8_0
#   - defaults/linux-64::ipykernel==5.3.4=py37h5ca1d4c_0
#   - defaults/noarch::tensorboard==2.4.0=pyhc547734_0
#   - defaults/noarch::prompt-toolkit==3.0.17=pyh06a4308_0
#   - defaults/linux-64::cx_oracle==8.2.1=py37h27cfd23_0
#   - defaults/noarch::importlib_metadata==3.10.0=hd3eb1b0_0
#   - defaults/noarch::mock==4.0.3=pyhd3eb1b0_0
#   - defaults/linux-64::pytorch==1.4.0=cpu_py37h7e40bad_0
#   - defaults/linux-64::gmp==6.2.1=h2531618_2
#   - defaults/noarch::snowballstemmer==2.1.0=pyhd3eb1b0_0
#   - defaults/noarch::tensorboard-plugin-wit==1.6.0=py_0
#   - defaults/noarch::jupyterlab_server==1.2.0=py_0
#   - defaults/linux-64::pillow==8.2.0=py37he98fc37_0
#   - defaults/linux-64::grpcio==1.36.1=py37h2157cd5_1
#   - defaults/noarch::click==8.0.1=pyhd3eb1b0_0
#   - defaults/noarch::ibm-wsrt-py37main-main==custom=2527
#   - defaults/noarch::dill==0.3.4=pyhd3eb1b0_0
#   - defaults/noarch::pyopenssl==20.0.1=pyhd3eb1b0_1
#   - defaults/noarch::wcwidth==0.2.5=py_0
#   - defaults/noarch::gast==0.4.0=py_0
#   - defaults/linux-64::numpy==1.19.2=py37h54aff64_0
#   - defaults/noarch::beautifulsoup4==4.9.3=pyha847dfd_0
#   - defaults/noarch::pygments==2.9.0=pyhd3eb1b0_0
#   - defaults/noarch::ptyprocess==0.7.0=pyhd3eb1b0_2
#   - defaults/noarch::networkx==2.5=py_0
#   - defaults/linux-64::pytest==6.2.4=py37h06a4308_2
#   - defaults/linux-64::pandocfilters==1.4.3=py37h06a4308_1
#   - defaults/linux-64::argon2-cffi==20.1.0=py37h27cfd23_1
#   - defaults/noarch::cachetools==4.2.2=pyhd3eb1b0_0
#   - defaults/linux-64::libstdcxx-ng==9.3.0=hd4cf53a_17
#   - defaults/noarch::decorator==5.0.9=pyhd3eb1b0_0
#   - defaults/noarch::nbclient==0.5.3=pyhd3eb1b0_0
#   - defaults/linux-64::kiwisolver==1.3.1=py37h2531618_0
#   - defaults/noarch::partd==1.2.0=pyhd3eb1b0_0
#   - defaults/linux-64::greenlet==1.1.0=py37h2531618_0
#   - defaults/noarch::astunparse==1.6.3=py_0
#   - defaults/noarch::google-auth==1.32.0=pyhd3eb1b0_0
#   - defaults/linux-64::expat==2.4.1=h2531618_2
#   - defaults/noarch::parso==0.8.2=pyhd3eb1b0_0
#   - defaults/noarch::urllib3==1.26.6=pyhd3eb1b0_1
#   - defaults/noarch::typing_extensions==3.10.0.0=pyh06a4308_0
#   - defaults/noarch::botocore==1.20.101=pyhd3eb1b0_1
#   - defaults/linux-64::setuptools==52.0.0=py37h06a4308_0
#   - defaults/linux-64::nbconvert==6.1.0=py37h06a4308_0
#   - defaults/noarch::testpath==0.5.0=pyhd3eb1b0_0
#   - defaults/linux-64::lz4-c==1.9.3=h2531618_0
#   - defaults/linux-64::tabulate==0.8.9=py37h06a4308_0
#   - defaults/linux-64::markdown==3.3.4=py37h06a4308_0
#   - defaults/linux-64::numexpr==2.7.3=py37hb2eb853_0
#   - defaults/noarch::requests==2.25.1=pyhd3eb1b0_0
#   - defaults/linux-64::unixodbc==2.3.9=h7b6447c_0
#   - defaults/linux-64::pandas==1.2.4=py37h2531618_0
#   - defaults/noarch::cloudpickle==1.6.0=py_0
#   - defaults/noarch::tqdm==4.61.2=pyhd3eb1b0_1
#   - defaults/linux-64::pyrsistent==0.17.3=py37h7b6447c_0
#   - defaults/noarch::opt_einsum==3.3.0=pyhd3eb1b0_1
#   - defaults/linux-64::sqlite==3.36.0=hc218d9a_0
#   - defaults/linux-64::readline==8.1=h27cfd23_0
#   - defaults/noarch::jeepney==0.6.0=pyhd3eb1b0_0
#   - defaults/linux-64::cytoolz==0.11.0=py37h7b6447c_0
#   - defaults/linux-64::mpc==1.1.0=h10f8cd9_1
#   - defaults/noarch::defusedxml==0.7.1=pyhd3eb1b0_0
#   - defaults/linux-64::secretstorage==3.3.1=py37h06a4308_0
#   - defaults/noarch::soupsieve==2.2.1=pyhd3eb1b0_0
#   - defaults/linux-64::gstreamer==1.14.0=h28cd5cc_2
#   - defaults/linux-64::numpy-base==1.19.2=py37hfa32c7d_0
#   - defaults/linux-64::bokeh==2.3.2=py37h06a4308_0
#   - defaults/linux-64::jupyter_core==4.7.1=py37h06a4308_0
#   - defaults/noarch::attrs==21.2.0=pyhd3eb1b0_0
#   - defaults/noarch::six==1.16.0=pyhd3eb1b0_0
#   - defaults/linux-64::tensorflow-base==2.4.1=mkl_py37h43e0292_0
#   - defaults/linux-64::scikit-learn==0.22.1=py37hd81dba3_0
#   - defaults/noarch::dask-core==2021.6.2=pyhd3eb1b0_0
#   - defaults/noarch::jmespath==0.10.0=py_0
#   - defaults/noarch::idna==2.10=pyhd3eb1b0_0
#   - defaults/linux-64::scipy==1.6.2=py37h91f5cce_0
#   - defaults/noarch::packaging==20.9=pyhd3eb1b0_0
#   - defaults/linux-64::tifffile==2020.10.1=py37hdd07704_2
#   - defaults/linux-64::matplotlib-base==3.3.4=py37h62a2d02_0
#   - defaults/linux-64::notebook==6.4.0=py37h06a4308_0
#   - defaults/noarch::ipywidgets==7.6.3=pyhd3eb1b0_1
#   - defaults/linux-64::libxml2==2.9.12=h03d6c58_0
#   - defaults/linux-64::docutils==0.17.1=py37h06a4308_1
#   - defaults/linux-64::absl-py==0.13.0=py37h06a4308_0
#   - defaults/noarch::json5==0.9.6=pyhd3eb1b0_0
#   - defaults/noarch::python-flatbuffers==1.12=pyhd3eb1b0_0
#   - defaults/linux-64::mkl_fft==1.3.0=py37h54f3939_0
#   - defaults/linux-64::glib==2.68.2=h36276a3_0
#   - defaults/noarch::seaborn==0.11.1=pyhd3eb1b0_0
#   - defaults/linux-64::async_generator==1.10=py37h28b3542_0
#   - defaults/noarch::typing-extensions==3.10.0.0=hd3eb1b0_0
#   - defaults/noarch::xlrd==2.0.1=pyhd3eb1b0_0
#   - defaults/linux-64::zeromq==4.3.4=h2531618_0
#   - defaults/linux-64::libxgboost==1.3.3=h2531618_0
#   - defaults/linux-64::pyzmq==20.0.0=py37h2531618_1
#   - defaults/noarch::google-auth-oauthlib==0.4.4=pyhd3eb1b0_0
#   - defaults/linux-64::py-xgboost==1.3.3=py37h06a4308_0
#   - defaults/noarch::toolz==0.11.1=pyhd3eb1b0_0
#   - defaults/noarch::more-itertools==8.8.0=pyhd3eb1b0_0
#   - defaults/linux-64::cython==0.29.23=py37h2531618_0
#   - defaults/noarch::s3transfer==0.4.2=pyhd3eb1b0_0
#   - defaults/linux-64::libgfortran-ng==7.5.0=ha8ba4b0_17
#   - defaults/linux-64::tornado==6.1=py37h27cfd23_0
#   - defaults/noarch::nest-asyncio==1.5.1=pyhd3eb1b0_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::mkl-service==2.3.0=py37he8ac12f_0
#   - defaults/linux-64::webencodings==0.5.1=py37_1
#   - defaults/noarch::pycparser==2.20=py_2
#   - defaults/linux-64::mkl_random==1.1.1=py37h0573a6f_0
#   - defaults/linux-64::pyqt==5.9.2=py37h05f1152_2
#   - defaults/linux-64::sip==4.19.8=py37hf484d3e_0
#   - defaults/linux-64::retrying==1.3.3=py37_2
#   - defaults/linux-64::pyodbc==4.0.30=py37he6710b0_0
#   - defaults/noarch::imageio==2.9.0=pyhd3eb1b0_0
#   - defaults/noarch::pyasn1-modules==0.2.8=py_0
#   - defaults/linux-64::cycler==0.10.0=py37_0
#   - defaults/noarch::send2trash==1.5.0=pyhd3eb1b0_1
#   - defaults/linux-64::keyring==18.0.0=py37_0
#   - defaults/noarch::pyparsing==2.4.7=pyhd3eb1b0_0
#   - defaults/linux-64::entrypoints==0.3=py37_0
#   - defaults/linux-64::future==0.18.2=py37_1
#   - defaults/linux-64::libuuid==1.0.3=h1bed415_2
#   - defaults/linux-64::qt==5.9.7=h5867ecd_1
#   - defaults/linux-64::pytables==3.6.1=py37h71ec239_0
#   - defaults/linux-64::snappy==1.1.8=he6710b0_0
#   - defaults/linux-64::lxml==4.6.3=py37h9120a33_0
#   - defaults/linux-64::hdf5==1.10.4=hb1b8bf9_0
#   - defaults/linux-64::pluggy==0.13.1=py37h06a4308_0
#   - defaults/linux-64::libwebp-base==1.2.0=h27cfd23_0
#   - defaults/linux-64::krb5==1.17.1=h173b8e3_0
#   - defaults/noarch::oauthlib==3.1.0=py_0
#   - defaults/linux-64::libpng==1.6.37=hbc83047_0
#   - defaults/noarch::google-pasta==0.2.0=py_0
#   - defaults/linux-64::certifi==2021.5.30=py37h06a4308_0
#   - defaults/linux-64::libpq==12.2=h20c2e04_0
#   - defaults/noarch::html5lib==1.1=py_0
#   - defaults/linux-64::libtiff==4.2.0=h85742a9_0
#   - defaults/linux-64::tk==8.6.10=hbc83047_0
#   - defaults/linux-64::pymssql==2.1.5=py37h7b6447c_0
#   - defaults/noarch::pyshp==2.1.0=py_0
#   - defaults/linux-64::pyjwt==1.7.1=py37_0
#   - defaults/linux-64::jpeg==9b=h024ee3a_2
#   - defaults/linux-64::bzip2==1.0.8=h7b6447c_0
#   - defaults/noarch::python-dateutil==2.8.1=pyhd3eb1b0_0
#   - defaults/linux-64::mistune==0.8.4=py37h14c3975_1001
#   - defaults/linux-64::blinker==1.4=py37h06a4308_0
#   - defaults/noarch::ipython_genutils==0.2.0=pyhd3eb1b0_1
#   - defaults/linux-64::cryptography==3.4.7=py37hd23ed53_0
#   - defaults/linux-64::lzo==2.10=h7b6447c_2
#   - defaults/linux-64::h5py==2.10.0=py37h7918eee_0
#   - defaults/noarch::jsonschema==3.2.0=py_2
#   - defaults/linux-64::pysocks==1.7.1=py37_1
#   - defaults/linux-64::wrapt==1.12.1=py37h7b6447c_1
#   - defaults/linux-64::ncurses==6.2=he6710b0_1
#   - defaults/linux-64::pywavelets==1.1.1=py37h7b6447c_2
#   - esri/linux-64::arcgis==1.6.0=py37h39e3cac_1
#   - defaults/noarch::jupyterlab==2.2.6=pyhd3eb1b0_1
#   - defaults/noarch::requests-oauthlib==1.3.0=py_0
#   - defaults/linux-64::yaml==0.2.5=h7b6447c_0
#   - defaults/linux-64::libxcb==1.14=h7b6447c_0
#   - defaults/linux-64::openssl==1.1.1k=h27cfd23_0
#   - defaults/linux-64::icu==58.2=he6710b0_3
#   - defaults/linux-64::patsy==0.5.1=py37_0
#   - defaults/linux-64::brotlipy==0.7.0=py37h27cfd23_1003
#   - defaults/linux-64::libxslt==1.1.34=hc22bd24_0
#   - defaults/noarch::keras-applications==1.0.8=py_1
#   - defaults/linux-64::olefile==0.46=py37_0
#   - defaults/noarch::pyasn1==0.4.8=py_0
#   - defaults/linux-64::widgetsnbextension==3.5.1=py37_0
#   - defaults/noarch::pexpect==4.8.0=pyhd3eb1b0_3
#   - defaults/linux-64::zlib==1.2.11=h7b6447c_3
#   - defaults/noarch::threadpoolctl==2.1.0=pyh5ca1d4c_0
#   - defaults/linux-64::libffi==3.3=he6710b0_2
#   - defaults/linux-64::fastcache==1.1.0=py37h7b6447c_0
#   - defaults/linux-64::pyyaml==5.4.1=py37h27cfd23_1
#   - defaults/linux-64::freetds==1.00.97=h52ef933_0
#   - defaults/noarch::backcall==0.2.0=pyhd3eb1b0_0
#   - defaults/linux-64::xz==5.2.5=h7b6447c_0
#   - defaults/noarch::werkzeug==1.0.1=pyhd3eb1b0_0
#   - defaults/linux-64::chardet==3.0.4=py37h06a4308_1003
#   - defaults/linux-64::async-timeout==3.0.1=py37h06a4308_0
#   - defaults/noarch::pickleshare==0.7.5=pyhd3eb1b0_1003
#   - defaults/linux-64::libsodium==1.0.18=h7b6447c_0
#   - defaults/linux-64::termcolor==1.1.0=py37h06a4308_1
#   - defaults/linux-64::yarl==1.6.3=py37h27cfd23_0
#   - defaults/noarch::traitlets==5.0.5=pyhd3eb1b0_0
#   - defaults/linux-64::pcre==8.45=h295c915_0
#   - defaults/linux-64::mpmath==1.2.1=py37h06a4308_0
#   - defaults/linux-64::blosc==1.21.0=h8c45485_0
#   - defaults/linux-64::fontconfig==2.13.1=h6c09931_0
#   - defaults/noarch::joblib==1.0.1=pyhd3eb1b0_0
#   - defaults/noarch::iniconfig==1.1.1=pyhd3eb1b0_0
#   - defaults/linux-64::libgcc-ng==9.3.0=h5101ec6_17
#   - defaults/noarch::tensorflow-estimator==2.5.0=pyh7b7c402_0
#   - defaults/linux-64::astropy==4.2.1=py37h27cfd23_1
#   - defaults/noarch::bleach==3.3.0=pyhd3eb1b0_0
#   - defaults/noarch::xlsxwriter==1.4.3=pyhd3eb1b0_0
#   - defaults/noarch::boto3==1.17.101=pyhd3eb1b0_0
#   - defaults/linux-64::markupsafe==2.0.1=py37h27cfd23_0
#   - defaults/linux-64::scikit-image==0.18.1=py37ha9443f7_0
#   - defaults/linux-64::multidict==5.1.0=py37h27cfd23_2
#   - defaults/linux-64::sympy==1.8=py37h06a4308_0
#   - defaults/linux-64::lcms2==2.12=h3be6417_0
#   - defaults/linux-64::locket==0.2.1=py37h06a4308_1
#   - defaults/linux-64::sqlalchemy==1.4.19=py37h7f8727e_0
#   - defaults/noarch::ibm-wsrt-py37main-keep==0.0.0=2527
#   - defaults/linux-64::regex==2021.4.4=py37h27cfd23_0
#   - defaults/noarch::nltk==3.6.2=pyhd3eb1b0_0
#   - defaults/noarch::zipp==3.4.1=pyhd3eb1b0_0
#   - defaults/linux-64::psycopg2==2.8.6=py37h3c74f83_1
#   - defaults/linux-64::gst-plugins-base==1.14.0=h8213a91_2
#   - defaults/linux-64::c-ares==1.17.1=h27cfd23_0
#   - defaults/noarch::wheel==0.36.2=pyhd3eb1b0_0
#   - defaults/linux-64::aiohttp==3.7.4=py37h27cfd23_1
#   - defaults/noarch::plotly==4.14.3=pyhd3eb1b0_0
#   - defaults/linux-64::jedi==0.17.0=py37_0
#   - defaults/linux-64::statsmodels==0.12.2=py37h27cfd23_0
#   - defaults/noarch::pytz==2021.1=pyhd3eb1b0_0
#   - defaults/linux-64::cffi==1.14.5=py37h261ae71_0
#   - defaults/linux-64::libedit==3.1.20210216=h27cfd23_1
#   - defaults/noarch::fsspec==2021.6.0=pyhd3eb1b0_0
#   - defaults/noarch::jupyterlab_widgets==1.0.0=pyhd3eb1b0_1
#   - defaults/linux-64::dbus==1.13.18=hb2f20db_0
#   - defaults/noarch::jinja2==3.0.1=pyhd3eb1b0_0
#   - defaults/noarch::rsa==4.7.2=pyhd3eb1b0_1
#   - defaults/noarch::toml==0.10.2=pyhd3eb1b0_0
#   - defaults/noarch::py==1.10.0=pyhd3eb1b0_0
#   - defaults/linux-64::zstd==1.4.9=haebb681_0
#   - defaults/linux-64::importlib-metadata==3.10.0=py37h06a4308_0
#   - defaults/linux-64::libprotobuf==3.14.0=h8c45485_0
#   - defaults/linux-64::matplotlib==3.3.4=py37h06a4308_0
#   - defaults/noarch::prometheus_client==0.11.0=pyhd3eb1b0_0
#   - defaults/linux-64::python==3.7.10=h12debd9_4
#   - defaults/linux-64::biopython==1.78=py37h7b6447c_0
#   - defaults/linux-64::freetype==2.10.4=h5ab3b9f_0
#   - defaults/noarch::keras-preprocessing==1.1.2=pyhd3eb1b0_0
#   - defaults/noarch::nbformat==5.1.3=pyhd3eb1b0_0
#   - defaults/linux-64::pip==21.1.3=py37h06a4308_0
#   - defaults/linux-64::ninja==1.10.2=hff7bd54_1
#   - defaults/linux-64::mpfr==4.0.2=hb69a4c5_1
#   - defaults/linux-64::protobuf==3.14.0=py37h2531618_1
#   - defaults/noarch::jupyter_client==6.1.12=pyhd3eb1b0_0
#   - defaults/linux-64::pyerfa==2.0.0=py37h27cfd23_0
#   - defaults/linux-64::terminado==0.9.4=py37h06a4308_0
#   - defaults/noarch::jupyterlab_pygments==0.1.2=py_0
#   - defaults/linux-64::coverage==5.5=py37h27cfd23_2
#   - defaults/linux-64::gmpy2==2.0.8=py37h10f8cd9_2
#   - defaults/linux-64::astor==0.8.1=py37h06a4308_0
#   - defaults/linux-64::ipython==7.22.0=py37hb070fc8_0
#   - defaults/linux-64::ipykernel==5.3.4=py37h5ca1d4c_0
#   - defaults/noarch::tensorboard==2.4.0=pyhc547734_0
#   - defaults/noarch::prompt-toolkit==3.0.17=pyh06a4308_0
#   - defaults/linux-64::cx_oracle==8.2.1=py37h27cfd23_0
#   - defaults/noarch::importlib_metadata==3.10.0=hd3eb1b0_0
#   - defaults/noarch::mock==4.0.3=pyhd3eb1b0_0
#   - defaults/linux-64::pytorch==1.4.0=cpu_py37h7e40bad_0
#   - defaults/linux-64::gmp==6.2.1=h2531618_2
#   - defaults/noarch::snowballstemmer==2.1.0=pyhd3eb1b0_0
#   - defaults/noarch::tensorboard-plugin-wit==1.6.0=py_0
#   - defaults/noarch::jupyterlab_server==1.2.0=py_0
#   - defaults/linux-64::pillow==8.2.0=py37he98fc37_0
#   - defaults/linux-64::grpcio==1.36.1=py37h2157cd5_1
#   - defaults/noarch::click==8.0.1=pyhd3eb1b0_0
#   - defaults/noarch::ibm-wsrt-py37main-main==custom=2527
#   - defaults/noarch::dill==0.3.4=pyhd3eb1b0_0
#   - defaults/noarch::pyopenssl==20.0.1=pyhd3eb1b0_1
#   - defaults/noarch::wcwidth==0.2.5=py_0
#   - defaults/noarch::gast==0.4.0=py_0
#   - defaults/linux-64::numpy==1.19.2=py37h54aff64_0
#   - defaults/noarch::beautifulsoup4==4.9.3=pyha847dfd_0
#   - defaults/noarch::pygments==2.9.0=pyhd3eb1b0_0
#   - defaults/noarch::ptyprocess==0.7.0=pyhd3eb1b0_2
#   - defaults/noarch::networkx==2.5=py_0
#   - defaults/linux-64::pytest==6.2.4=py37h06a4308_2
#   - defaults/linux-64::pandocfilters==1.4.3=py37h06a4308_1
#   - defaults/linux-64::argon2-cffi==20.1.0=py37h27cfd23_1
#   - defaults/noarch::cachetools==4.2.2=pyhd3eb1b0_0
#   - defaults/linux-64::libstdcxx-ng==9.3.0=hd4cf53a_17
#   - defaults/noarch::decorator==5.0.9=pyhd3eb1b0_0
#   - defaults/noarch::nbclient==0.5.3=pyhd3eb1b0_0
#   - defaults/linux-64::kiwisolver==1.3.1=py37h2531618_0
#   - defaults/noarch::partd==1.2.0=pyhd3eb1b0_0
#   - defaults/linux-64::greenlet==1.1.0=py37h2531618_0
#   - defaults/noarch::astunparse==1.6.3=py_0
#   - defaults/noarch::google-auth==1.32.0=pyhd3eb1b0_0
#   - defaults/linux-64::expat==2.4.1=h2531618_2
#   - defaults/noarch::parso==0.8.2=pyhd3eb1b0_0
#   - defaults/noarch::urllib3==1.26.6=pyhd3eb1b0_1
#   - defaults/noarch::typing_extensions==3.10.0.0=pyh06a4308_0
#   - defaults/noarch::botocore==1.20.101=pyhd3eb1b0_1
#   - defaults/linux-64::setuptools==52.0.0=py37h06a4308_0
#   - defaults/linux-64::nbconvert==6.1.0=py37h06a4308_0
#   - defaults/noarch::testpath==0.5.0=pyhd3eb1b0_0
#   - defaults/linux-64::lz4-c==1.9.3=h2531618_0
#   - defaults/linux-64::tabulate==0.8.9=py37h06a4308_0
#   - defaults/linux-64::markdown==3.3.4=py37h06a4308_0
#   - defaults/linux-64::numexpr==2.7.3=py37hb2eb853_0
#   - defaults/noarch::requests==2.25.1=pyhd3eb1b0_0
#   - defaults/linux-64::unixodbc==2.3.9=h7b6447c_0
#   - defaults/linux-64::pandas==1.2.4=py37h2531618_0
#   - defaults/noarch::cloudpickle==1.6.0=py_0
#   - defaults/noarch::tqdm==4.61.2=pyhd3eb1b0_1
#   - defaults/linux-64::pyrsistent==0.17.3=py37h7b6447c_0
#   - defaults/noarch::opt_einsum==3.3.0=pyhd3eb1b0_1
#   - defaults/linux-64::sqlite==3.36.0=hc218d9a_0
#   - defaults/linux-64::readline==8.1=h27cfd23_0
#   - defaults/noarch::jeepney==0.6.0=pyhd3eb1b0_0
#   - defaults/linux-64::cytoolz==0.11.0=py37h7b6447c_0
#   - defaults/linux-64::mpc==1.1.0=h10f8cd9_1
#   - defaults/noarch::defusedxml==0.7.1=pyhd3eb1b0_0
#   - defaults/linux-64::secretstorage==3.3.1=py37h06a4308_0
#   - defaults/noarch::soupsieve==2.2.1=pyhd3eb1b0_0
#   - defaults/linux-64::gstreamer==1.14.0=h28cd5cc_2
#   - defaults/linux-64::numpy-base==1.19.2=py37hfa32c7d_0
#   - defaults/linux-64::bokeh==2.3.2=py37h06a4308_0
#   - defaults/linux-64::jupyter_core==4.7.1=py37h06a4308_0
#   - defaults/noarch::attrs==21.2.0=pyhd3eb1b0_0
#   - defaults/noarch::six==1.16.0=pyhd3eb1b0_0
#   - defaults/linux-64::tensorflow-base==2.4.1=mkl_py37h43e0292_0
#   - defaults/linux-64::scikit-learn==0.22.1=py37hd81dba3_0
#   - defaults/noarch::dask-core==2021.6.2=pyhd3eb1b0_0
#   - defaults/noarch::jmespath==0.10.0=py_0
#   - defaults/noarch::idna==2.10=pyhd3eb1b0_0
#   - defaults/linux-64::scipy==1.6.2=py37h91f5cce_0
#   - defaults/noarch::packaging==20.9=pyhd3eb1b0_0
#   - defaults/linux-64::tifffile==2020.10.1=py37hdd07704_2
#   - defaults/linux-64::matplotlib-base==3.3.4=py37h62a2d02_0
#   - defaults/linux-64::notebook==6.4.0=py37h06a4308_0
#   - defaults/noarch::ipywidgets==7.6.3=pyhd3eb1b0_1
#   - defaults/linux-64::libxml2==2.9.12=h03d6c58_0
#   - defaults/linux-64::docutils==0.17.1=py37h06a4308_1
#   - defaults/linux-64::absl-py==0.13.0=py37h06a4308_0
#   - defaults/noarch::json5==0.9.6=pyhd3eb1b0_0
#   - defaults/noarch::python-flatbuffers==1.12=pyhd3eb1b0_0
#   - defaults/linux-64::mkl_fft==1.3.0=py37h54f3939_0
#   - defaults/linux-64::glib==2.68.2=h36276a3_0
#   - defaults/noarch::seaborn==0.11.1=pyhd3eb1b0_0
#   - defaults/linux-64::async_generator==1.10=py37h28b3542_0
#   - defaults/noarch::typing-extensions==3.10.0.0=hd3eb1b0_0
#   - defaults/noarch::xlrd==2.0.1=pyhd3eb1b0_0
#   - defaults/linux-64::zeromq==4.3.4=h2531618_0
#   - defaults/linux-64::libxgboost==1.3.3=h2531618_0
#   - defaults/linux-64::pyzmq==20.0.0=py37h2531618_1
#   - defaults/noarch::google-auth-oauthlib==0.4.4=pyhd3eb1b0_0
#   - defaults/linux-64::py-xgboost==1.3.3=py37h06a4308_0
#   - defaults/noarch::toolz==0.11.1=pyhd3eb1b0_0
#   - defaults/noarch::more-itertools==8.8.0=pyhd3eb1b0_0
#   - defaults/linux-64::cython==0.29.23=py37h2531618_0
#   - defaults/noarch::s3transfer==0.4.2=pyhd3eb1b0_0
#   - defaults/linux-64::libgfortran-ng==7.5.0=ha8ba4b0_17
#   - defaults/linux-64::tornado==6.1=py37h27cfd23_0
#   - defaults/noarch::nest-asyncio==1.5.1=pyhd3eb1b0_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: -
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
#                                                                                                          -failed
#
# UnsatisfiableError: The following specifications were found to be incompatible with a past
# explicit spec that is not an explicit spec in this operation (seaborn):
#
#   - seaborn
#
# The following specifications were found to be incompatible with each other:
#
# Output in format: Requested package -> Available versions
#
# Package c-ares conflicts for:
# ibm-wsrt-py37main-main -> c-ares==1.15.0[build=*]
# grpcio -> c-ares[version='>=1.15.0,<2.0a0|>=1.17.1,<2.0a0']
# c-ares
#
# Package async_generator conflicts for:
# async_generator
# nbclient -> async_generator
#
# Package cycler conflicts for:
# matplotlib-base -> cycler[version='>=0.10']
# matplotlib -> cycler[version='>=0.10']
# cycler
# ibm-wsrt-py37main-main -> cycler==0.10.0[build=*]
#
# Package libgcc-ng conflicts for:
# blosc -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# grpcio -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# fastcache -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libtiff -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# numpy -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# c-ares -> libgcc-ng[version='>=7.3.0']
# mpfr -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# dbus -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libpng -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# brotlipy -> libgcc-ng[version='>=7.3.0']
# pyodbc -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# sip -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# openssl -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# kiwisolver -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# numexpr -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# libxslt -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# krb5 -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# mistune -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# ncurses -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# mkl-service -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# multidict -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# libxcb -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# gmpy2 -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# lcms2 -> libgcc-ng[version='>=7.3.0']
# libxml2 -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=9.3.0']
# tensorboard -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# sqlalchemy -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# cx_oracle -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# pyrsistent -> libgcc-ng[version='>=7.3.0|>=7.5.0']
# zstd -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# psycopg2 -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# pyzmq -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# tornado -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# pyyaml -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# aiohttp -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libffi -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0']
# matplotlib -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# jpeg -> libgcc-ng[version='7.2.0.*|>=7.2.0']
# mpc -> libgcc-ng[version='7.2.0.*|>=7.2.0']
# libuuid -> libgcc-ng[version='>=7.2.0']
# statsmodels -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# markupsafe -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libxgboost -> libgcc-ng[version='>=5.4.0|>=7.3.0|>=7.2.0']
# tk -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0']
# freetds -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# expat -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0']
# fontconfig -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# gmp -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# libpq -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# pytorch -> libgcc-ng[version='>=5.4.0|>=7.3.0|>=7.5.0']
# wrapt -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# sqlite -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0']
# scikit-learn -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# readline -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0']
# numpy-base -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# cffi -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# pyqt -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# bzip2 -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# libsodium -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# libwebp-base -> libgcc-ng[version='>=7.3.0']
# yaml -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0']
# biopython -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# yarl -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# lz4-c -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# coverage -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# pywavelets -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# gstreamer -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# tifffile -> libgcc-ng[version='>=7.3.0']
# freetype -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# mkl_fft -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libedit -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# scikit-image -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# python=3.7 -> libgcc-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# pcre -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0']
# gst-plugins-base -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# icu -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0']
# qt -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# pillow -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# xz -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# unixodbc -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libgcc-ng
# py-xgboost -> libgcc-ng[version='>=5.4.0|>=7.3.0|>=7.2.0']
# matplotlib-base -> libgcc-ng[version='>=7.3.0']
# lzo -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0']
# cryptography -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# scipy -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# cython -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# protobuf -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# pytables -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# libprotobuf -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# mkl_random -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# pymssql -> libgcc-ng[version='>=7.3.0']
# ninja -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# zlib -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0']
# argon2-cffi -> libgcc-ng[version='>=7.3.0']
# greenlet -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# zeromq -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# h5py -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# astropy -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# pyerfa -> libgcc-ng[version='>=7.3.0']
# hdf5 -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# snappy -> libgcc-ng[version='7.2.0.*|>=7.3.0|>=7.2.0']
# cytoolz -> libgcc-ng[version='>=7.2.0|>=7.3.0']
# tensorflow-base -> libgcc-ng[version='>=5.4.0|>=7.2.0']
# regex -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# ibm-wsrt-py37main-main -> libgcc-ng==9.1.0[build=*]
# lxml -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# pandas -> libgcc-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0']
#
# Package freetype conflicts for:
# freetype
# matplotlib -> freetype[version='>=2.8,<2.9.0a0|>=2.9.1,<3.0a0']
# matplotlib-base -> freetype[version='>=2.10.2,<3.0a0|>=2.9.1,<3.0a0|>=2.10.4,<3.0a0']
# fontconfig -> freetype[version='>=2.10.4,<3.0a0|>=2.8,<2.9.0a0|>=2.9,<3.0a0|>=2.9.1,<3.0a0']
# qt -> freetype[version='>=2.8,<2.9.0a0|>=2.9.1,<3.0a0']
# ibm-wsrt-py37main-main -> freetype==2.10.2[build=*]
# pillow -> freetype[version='>=2.10.3,<3.0a0|>=2.9.1,<3.0a0|>=2.8,<2.9.0a0|>=2.10.4,<3.0a0']
#
# Package numpy conflicts for:
# mkl_fft -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16,<2.0a0|>=1.16.6,<2.0a0']
# numpy
# statsmodels -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.17.0,<2.0a0|>=1.19.1,<2.0a0|>=1.9.3,<2.0a0|>=1.19.2,<2.0a0']
# matplotlib-base -> numpy[version='>=1.14.6,<2.0a0|>=1.15.4,<2.0a0|>=1.16.6,<2.0a0']
# imageio -> numpy
# mkl-service -> numpy[version='>=1.11.3,<2.0a0']
# keras-applications -> numpy[version='>=1.9.1']
# tifffile -> numpy[version='>=1.11.3,<2.0a0|>=1.15.1|>=1.14.6,<2.0a0']
# scikit-learn -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.9.3,<2.0a0|>=1.16.6,<2.0a0']
# tensorflow-base -> numpy[version='>=1.12.1,<2.0a0|>=1.13.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.5,<2.0a0|>=1.16.6,<2.0a0|>=1.20']
# opt_einsum -> numpy
# py-xgboost -> numpy
# seaborn -> numpy[version='>=1.13.3|>=1.9.3']
# tensorboard -> numpy[version='>=1.12|>=1.12.0|>=1.16']
# nltk -> numpy
# pytables -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.9.3,<2.0a0|>=1.16.6,<2.0a0']
# arcgis -> numpy
# pandas -> numpy[version='>=1.11.3,<2.0a0|>=1.12.1,<2.0a0|>=1.13.3,<2.0a0|>=1.14.6,<2.0a0|>=1.15.4,<2.0a0|>=1.16.6,<2.0a0|>=1.9.3,<2.0a0|>=1.9|>=1.20.2,<2.0a0|>=1.19.2,<2.0a0']
# scipy -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.15.1,<2.0a0|>=1.9.3,<2.0a0|>=1.16.6,<2.0a0']
# patsy -> numpy[version='>=1.4.0']
# numexpr -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.4,<2.0a0|>=1.15.4,<2.0a0|>=1.9.3,<2.0a0|>=1.16.6,<2.0a0']
# mkl_random -> numpy[version='>=1.11.3,<2.0a0|>=1.14,<2.0a0|>=1.14.6,<2.0a0|>=1.16,<2.0a0']
# matplotlib -> numpy[version='>=1.14.6,<2.0a0']
# scikit-image -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.6,<2.0a0|>=1.9.3,<2.0a0|>=1.13.3,<2.0a0']
# ibm-wsrt-py37main-main -> numpy==1.18.5[build=*]
# tensorflow-estimator -> numpy[version='>=1.13.3|>=1.16.1']
# astropy -> numpy[version='>=1.10.4,<2.0a0|>=1.11.3,<2.0a0|>=1.13.3,<2.0a0|>=1.16.5,<2.0a0|>=1.16.6,<2.0a0|>=1.17.4,<2.0a0|>=1.14.6,<2.0a0|>=1.11|>=1.9|>=1.14|>=1.9.3,<2.0a0|>=1.14.1,<2.0a0|>=1.14.0,<2.0a0|>=1.17|>=1.17.0,<2.0a0']
# pyerfa -> numpy[version='>=1.17|>=1.17.0,<2.0a0|>=1.20.1,<2.0a0|>=1.19.2,<2.0a0']
# h5py -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.16.6,<2.0a0']
# pywavelets -> numpy[version='>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.9.3,<2.0a0|>=1.16.6,<2.0a0']
# bokeh -> numpy[version='>=1.11.3|>=1.7.1']
# keras-preprocessing -> numpy[version='>=1.9.1']
# biopython -> numpy[version='>=1.11.3,<2.0a0|>=1.9.3,<2.0a0|>=1.14.1,<2.0a0']
# pytorch -> numpy[version='>=1.11|>=1.11.3,<2.0a0|>=1.14.6,<2.0a0|>=1.9.3,<2.0a0|>=1.9|>=1.16.6,<2.0a0']
#
# Package snappy conflicts for:
# snappy
# tensorflow-base -> snappy[version='>=1.1.8,<2.0a0']
# blosc -> snappy[version='>=1.1.7,<2.0a0|>=1.1.8,<2.0a0']
# ibm-wsrt-py37main-main -> snappy==1.1.8[build=*]
#
# Package cffi conflicts for:
# pytorch -> cffi
# ibm-wsrt-py37main-main -> cffi==1.14.0[build=*]
# argon2-cffi -> cffi[version='>=1.0.0']
# cffi
# brotlipy -> cffi[version='>=1.0.0']
# cryptography -> cffi[version='!=1.11.3,>=1.8|>=1.8|>=1.7|>=1.12']
#
# Package libstdcxx-ng conflicts for:
# pcre -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0']
# greenlet -> libstdcxx-ng[version='>=7.3.0']
# zstd -> libstdcxx-ng[version='>=7.3.0']
# cython -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# pandas -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0|>=7.5.0']
# pytorch -> libstdcxx-ng[version='>=5.4.0|>=7.3.0|>=7.5.0']
# pyqt -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# scikit-learn -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# matplotlib -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# tensorflow-base -> libstdcxx-ng[version='>=5.4.0|>=7.2.0']
# qt -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# lz4-c -> libstdcxx-ng[version='>=7.3.0']
# snappy -> libstdcxx-ng[version='7.2.0.*|>=7.3.0|>=7.2.0']
# matplotlib-base -> libstdcxx-ng[version='>=7.3.0']
# ibm-wsrt-py37main-main -> libstdcxx-ng==9.1.0[build=*]
# pyzmq -> libstdcxx-ng[version='>=7.3.0']
# pytables -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# numexpr -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# libtiff -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# sip -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# libxgboost -> libstdcxx-ng[version='>=5.4.0|>=7.3.0|>=7.2.0']
# hdf5 -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# protobuf -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# libffi -> libstdcxx-ng[version='7.2.0.*|>=7.3.0|>=7.2.0']
# mkl_fft -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# pyodbc -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# kiwisolver -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# gmp -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# zeromq -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# expat -> libstdcxx-ng[version='7.2.0.*|>=7.3.0|>=7.2.0']
# grpcio -> libstdcxx-ng[version='>=7.2.0|>=7.3.0|>=7.5.0']
# ninja -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# python=3.7 -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# libstdcxx-ng
# icu -> libstdcxx-ng[version='7.2.0.*|>=7.3.0|>=7.2.0']
# ncurses -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# libprotobuf -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# blosc -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# mkl_random -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# scikit-image -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# biopython -> libstdcxx-ng[version='>=7.2.0']
# gst-plugins-base -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# scipy -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# tensorboard -> libstdcxx-ng[version='>=7.2.0|>=7.3.0']
# krb5 -> libstdcxx-ng[version='7.2.0.*|>=7.2.0|>=7.3.0']
# py-xgboost -> libstdcxx-ng[version='>=5.4.0|>=7.3.0|>=7.2.0']
#
# Package blas conflicts for:
# scipy -> blas[version='*|*|1.0|1.0',build='mkl|mkl|openblas|openblas']
# numexpr -> blas[version='*|*|1.0|1.0',build='mkl|mkl|openblas|openblas']
# numpy -> blas[version='*|*|1.0|1.0',build='mkl|mkl|openblas|openblas']
# mkl-service -> blas==1.0=mkl
# numpy-base -> blas[version='*|*|1.0|1.0',build='mkl|mkl|openblas|openblas']
# mkl_fft -> blas[version='*|1.0',build=mkl]
# blas
# scikit-learn -> blas[version='*|*|1.0|1.0',build='mkl|mkl|openblas|openblas']
# ibm-wsrt-py37main-main -> blas==1.0[build=*]
# mkl_random -> blas[version='*|1.0',build=mkl]
# pytorch -> blas==1.0=mkl
#
# Package pickleshare conflicts for:
# ibm-wsrt-py37main-main -> pickleshare==0.7.5[build=*]
# pickleshare
# ipython -> pickleshare
#
# Package pexpect conflicts for:
# ipython -> pexpect[version='>4.3']
# ibm-wsrt-py37main-main -> pexpect==4.8.0[build=*]
# pexpect
#
# Package ipywidgets conflicts for:
# arcgis -> ipywidgets[version='>=7']
# ipywidgets
# ibm-wsrt-py37main-keep -> ipywidgets=[build=*]
# ibm-wsrt-py37main-main -> ipywidgets==7.5.1[build=*]
#
# Package imageio conflicts for:
# scikit-image -> imageio[version='>=2.1.0|>=2.3.0']
# imageio
# ibm-wsrt-py37main-main -> imageio==2.9.0[build=*]
#
# Package matplotlib conflicts for:
# ibm-wsrt-py37main-main -> matplotlib==3.2.2[build=*]
# bokeh -> matplotlib
# seaborn -> matplotlib[version='>=1.4.3|>=2.1.2']
# matplotlib
# nltk -> matplotlib
# scikit-image -> matplotlib[version='>=1.3.1|>=2.0.0']
# arcgis -> matplotlib
# ibm-wsrt-py37main-keep -> matplotlib=[build=*]
# astropy -> matplotlib[version='>=3.0']
#
# Package xz conflicts for:
# libxml2 -> xz[version='>=5.2.3,<6.0a0|>=5.2.4,<6.0a0|>=5.2.5,<6.0a0']
# ibm-wsrt-py37main-main -> xz==5.2.5[build=*]
# python=3.7 -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<6.0a0']
# xz
# gstreamer -> xz[version='>=5.2.3,<6.0a0']
# libtiff -> xz[version='>=5.2.3,<6.0a0|>=5.2.4,<6.0a0|>=5.2.5,<6.0a0']
# gst-plugins-base -> xz[version='>=5.2.3,<6.0a0']
# zstd -> xz[version='>=5.2.4,<6.0a0|>=5.2.5,<6.0a0']
#
# Package werkzeug conflicts for:
# tensorflow-base -> werkzeug[version='>=0.14.1,<1.0a0']
# ibm-wsrt-py37main-main -> werkzeug==1.0.1[build=*]
# tensorboard -> werkzeug[version='>=0.11.10|>=0.11.15|>=0.14']
# werkzeug
#
# Package oauthlib conflicts for:
# oauthlib
# ibm-wsrt-py37main-main -> oauthlib==3.1.0[build=*]
# requests-oauthlib -> oauthlib[version='>=0.6.2|>=3.0.0']
#
# Package mpc conflicts for:
# gmpy2 -> mpc
# mpc
#
# Package mpfr conflicts for:
# mpc -> mpfr[version='3.*|>=4.0.1,<5.0a0']
# gmpy2 -> mpfr[version='3.*|>=4.0.1,<5.0a0|>=4.0.2,<5.0a0']
# mpfr
#
# Package py-xgboost conflicts for:
# py-xgboost
# ibm-wsrt-py37main-keep -> py-xgboost=[build=*]
# ibm-wsrt-py37main-main -> py-xgboost==0.90[build=*]
#
# Package importlib-metadata conflicts for:
# ibm-wsrt-py37main-main -> importlib-metadata==1.6.1[build=*]
# pytest -> importlib-metadata[version='>=0.12']
# importlib-metadata
# markdown -> importlib-metadata
# importlib_metadata -> importlib-metadata[version='>=1.1.3,<1.1.4.0a0|>=1.6.0,<1.6.1.0a0|>=1.6.1,<1.6.2.0a0|>=1.7.0,<1.7.1.0a0|>=2.0.0,<2.0.1.0a0|>=3.10.0,<3.10.1.0a0|>=3.7.3,<3.7.4.0a0']
# click -> importlib-metadata
# sqlalchemy -> importlib-metadata
# keyring -> importlib-metadata
#
# Package keyring conflicts for:
# ibm-wsrt-py37main-main -> keyring==18.0.0[build=*]
# arcgis -> keyring
# keyring
# ibm-wsrt-py37main-keep -> keyring==18.0.0[build=*]
#
# Package joblib conflicts for:
# ibm-wsrt-py37main-main -> joblib==0.16.0[build=*]
# nltk -> joblib
# joblib
# scikit-learn -> joblib[version='>=0.11']
#
# Package prometheus_client conflicts for:
# prometheus_client
# ibm-wsrt-py37main-main -> prometheus_client==0.8.0[build=*]
# notebook -> prometheus_client
#
# Package entrypoints conflicts for:
# ibm-wsrt-py37main-main -> entrypoints==0.3[build=*]
# jupyter_client -> entrypoints
# keyring -> entrypoints
# nbconvert -> entrypoints[version='>=0.2.2']
# entrypoints
#
# Package openssl conflicts for:
# ibm-wsrt-py37main-main -> openssl==1.1.1k[build=*]
# grpcio -> openssl[version='>=1.0.2p,<1.0.3a|>=1.1.1,<1.1.2.0a0|>=1.1.1d,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1a,<1.1.2a']
# libpq -> openssl[version='>=1.0.2m,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1d,<1.1.2a']
# krb5 -> openssl[version='1.0.*|>=1.0.2l,<1.0.3a|>=1.0.2m,<1.0.3a|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1,<1.1.2.0a0|>=1.1.1d,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1a,<1.1.2a']
# qt -> openssl[version='1.0.*|1.1.*|>=1.0.2p,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2n,<1.0.3a']
# cryptography -> openssl[version='1.0.*|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1,<1.1.2.0a0|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1h,<1.1.2a|>=1.0.2n,<1.0.3a|>=1.0.2m,<1.0.3a|>=1.1.1k,<1.1.2a|>=1.1.1j,<1.1.2a|>=1.1.1i,<1.1.2a']
# freetds -> openssl[version='>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1,<1.1.2.0a0|>=1.1.1e,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1i,<1.1.2a|>=1.1.1a,<1.1.2a']
# tensorflow-base -> openssl[version='>=1.1.1k,<1.1.2a']
# psycopg2 -> openssl[version='1.0.*|>=1.0.2n,<1.0.3a|>=1.0.2o,<1.0.3a|>=1.1.1a,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.0.2m,<1.0.3a']
# python=3.7 -> openssl[version='>=1.0.2o,<1.0.3a|>=1.0.2p,<1.0.3a|>=1.1.1,<1.1.2.0a0|>=1.1.1a,<1.1.2a|>=1.1.1b,<1.1.2a|>=1.1.1c,<1.1.2a|>=1.1.1d,<1.1.2a|>=1.1.1e,<1.1.2a|>=1.1.1g,<1.1.2a|>=1.1.1k,<1.1.2a|>=1.1.1j,<1.1.2a']
# openssl
#
# Package pyopenssl conflicts for:
# google-auth -> pyopenssl[version='>=20.0.0']
# pyopenssl
# ibm-wsrt-py37main-main -> pyopenssl==19.1.0[build=*]
# urllib3 -> pyopenssl[version='>=0.14']
#
# Package toolz conflicts for:
# ibm-wsrt-py37main-main -> toolz==0.10.0[build=*]
# toolz
# cytoolz -> toolz[version='>=0.10.0|>=0.8.0']
# partd -> toolz
# dask-core -> toolz[version='>=0.8.2']
# scikit-image -> toolz[version='>=0.7.3|>=0.7.4']
#
# Package nltk conflicts for:
# ibm-wsrt-py37main-keep -> nltk=[build=*]
# nltk
# ibm-wsrt-py37main-main -> nltk==3.5.0[build=*]
#
# Package gast conflicts for:
# ibm-wsrt-py37main-main -> gast==0.2.2[build=*]
# tensorflow-base -> gast[version='0.4.0|>=0.2.0|>=0.2.2,<0.2.3.0a0|>=0.3.3,<0.3.4.0a0|>=0.4.0,<0.4.1.0a0']
# gast
# tensorflow-estimator -> gast[version='>=0.2.0']
#
# Package s3transfer conflicts for:
# s3transfer
# boto3 -> s3transfer[version='>=0.1.10,<0.2.0|>=0.2.0,<0.3.0|>=0.3.0,<0.4.0|>=0.4.0,<0.5.0']
# ibm-wsrt-py37main-main -> s3transfer==0.3.3[build=*]
#
# Package absl-py conflicts for:
# tensorflow-base -> absl-py[version='>=0.1.6|>=0.7.0|>=0.7.1,<1.0a0|>=0.7.1|>=0.8.1|>=0.10.0|>=0.11.0']
# absl-py
# tensorflow-estimator -> absl-py[version='>=0.1.6|>=0.7.0']
# ibm-wsrt-py37main-main -> absl-py==0.9.0[build=*]
# tensorboard -> absl-py[version='>=0.4|>=0.7']
#
# Package pathlib2 conflicts for:
# pickleshare -> pathlib2
# ipython -> pathlib2
# testpath -> pathlib2
# importlib_metadata -> pathlib2
# pytest -> pathlib2[version='>=2.2.0']
#
# Package prompt-toolkit conflicts for:
# prompt-toolkit
# ipython -> prompt-toolkit[version='!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0']
# ibm-wsrt-py37main-main -> prompt-toolkit==3.0.5[build=*]
#
# Package sqlalchemy conflicts for:
# ibm-wsrt-py37main-keep -> sqlalchemy=[build=*]
# ibm-wsrt-py37main-main -> sqlalchemy==1.3.17[build=*]
# sqlalchemy
#
# Package cryptography conflicts for:
# pyopenssl -> cryptography[version='>=1.9|>=2.1.4|>=2.2.1|>=2.8']
# oauthlib -> cryptography[version='>=3.0.0,<4']
# google-auth-oauthlib -> cryptography[version='>=3.2']
# urllib3 -> cryptography[version='>=1.3.4']
# pyjwt -> cryptography[version='>=1.0|>=1.4|>=2.6,<3.0.0']
# secretstorage -> cryptography
# cryptography
# ibm-wsrt-py37main-main -> cryptography==3.4.7[build=*]
#
# Package pcre conflicts for:
# ibm-wsrt-py37main-main -> pcre==8.44[build=*]
# pcre
# gstreamer -> pcre[version='>=8.42,<9.0a0']
#
# Package ipython conflicts for:
# ipykernel -> ipython[version='>=4.0.0|>=4.0|>=5.0']
# jupyterlab -> ipython
# ipywidgets -> ipython[version='>=4.0.0']
# ipython
# ibm-wsrt-py37main-main -> ipython==7.15.0[build=*]
#
# Package ipykernel conflicts for:
# notebook -> ipykernel
# ipywidgets -> ipykernel[version='>=4.5.1']
# ipykernel
# ibm-wsrt-py37main-keep -> ipykernel=[build=*]
# ibm-wsrt-py37main-main -> ipykernel==5.3.0[build=*]
#
# Package pyzmq conflicts for:
# ibm-wsrt-py37main-main -> pyzmq==19.0.1[build=*]
# notebook -> pyzmq[version='>=17']
# pyzmq
# jupyter_client -> pyzmq[version='>=13']
#
# Package zlib conflicts for:
# python=3.7 -> zlib[version='>=1.2.11,<1.3.0a0']
# zlib
# tensorflow-base -> zlib[version='>=1.2.11,<1.3.0a0']
# pillow -> zlib[version='>=1.2.11,<1.3.0a0']
# zstd -> zlib[version='>=1.2.11,<1.3.0a0']
# ibm-wsrt-py37main-main -> zlib==1.2.11[build=*]
# libprotobuf -> zlib[version='>=1.2.11,<1.3.0a0']
# qt -> zlib[version='>=1.2.11,<1.3.0a0']
# freetype -> zlib[version='>=1.2.11,<1.3.0a0']
# gst-plugins-base -> zlib[version='>=1.2.11,<1.3.0a0']
# pandoc -> zlib
# libxml2 -> zlib[version='>=1.2.11,<1.3.0a0']
# libpng -> zlib[version='>=1.2.11,<1.3.0a0']
# sqlite -> zlib[version='>=1.2.11,<1.3.0a0']
# libpq -> zlib[version='>=1.2.11,<1.3.0a0']
# blosc -> zlib[version='>=1.2.11,<1.3.0a0']
# grpcio -> zlib[version='>=1.2.11,<1.3.0a0']
# pytables -> zlib[version='>=1.2.11,<1.3.0a0']
# matplotlib -> zlib[version='>=1.2.11,<1.3.0a0']
# hdf5 -> zlib[version='1.2.*|>=1.2.11,<1.3.0a0']
# tk -> zlib[version='>=1.2.11,<1.3.0a0']
# libtiff -> zlib[version='>=1.2.11,<1.3.0a0']
#
# Package futures conflicts for:
# tornado -> futures
# jupyterlab -> futures
# tensorboard -> futures[version='>=3.1.1']
# bokeh -> futures[version='>=3.0.3']
# grpcio -> futures[version='>=2.2.0']
# imageio -> futures
# s3transfer -> futures[version='>=2.2.0,<4.0.0']
#
# Package pytorch conflicts for:
# ibm-wsrt-py37main-main -> pytorch==1.3.1[build=cpu_*]
# ...
#
# Package bokeh conflicts for:
# ibm-wsrt-py37main-main -> bokeh==2.1.1[build=*]
# ibm-wsrt-py37main-keep -> bokeh=[build=*]
# bokeh
#
# Package gmp conflicts for:
# gmp
# mpc -> gmp[version='>=5.0.1,<7|>=6.1.2']
# gmpy2 -> gmp[version='>=6.1.2']
# ibm-wsrt-py37main-main -> gmp==6.1.2[build=*]
# pandoc -> gmp
# mpfr -> gmp[version='>=6.1.2']
#
# Package rsa conflicts for:
# rsa
# google-auth -> rsa[version='>=3.1.4,<4.1|>=3.1.4,<5']
# ibm-wsrt-py37main-main -> rsa==4.6[build=*]
#
# Package _libgcc_mutex conflicts for:
# libgomp -> _libgcc_mutex==0.1=main
# _libgcc_mutex
# _openmp_mutex -> _libgcc_mutex==0.1=main
# libgcc-ng -> _libgcc_mutex[version='*|0.1',build=main]
# ibm-wsrt-py37main-main -> _libgcc_mutex==0.1[build=*]
#
# Package jupyterlab conflicts for:
# arcgis -> jupyterlab
# ibm-wsrt-py37main-main -> jupyterlab==2.2.6[build=*]
# ibm-wsrt-py37main-keep -> jupyterlab==2.2.6[build=*]
# jupyterlab
#
# Package pyjwt conflicts for:
# ibm-wsrt-py37main-main -> pyjwt==1.7.1[build=*]
# pyjwt
# oauthlib -> pyjwt[version='>=1.0.0|>=2.0.0,<3']
#
# Package tk conflicts for:
# pillow -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# krb5 -> tk[version='8.6.*|>=8.6.7,<8.7.0a0|>=8.6.8,<8.7.0a0']
# matplotlib-base -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0']
# tk
# ibm-wsrt-py37main-main -> tk==8.6.10[build=*]
# python=3.7 -> tk[version='>=8.6.10,<8.7.0a0|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
# matplotlib -> tk[version='8.6.*|>=8.6.8,<8.7.0a0|>=8.6.7,<8.7.0a0']
#
# Package pyodbc conflicts for:
# pyodbc
# ibm-wsrt-py37main-main -> pyodbc==4.0.30[build=*]
# ibm-wsrt-py37main-keep -> pyodbc=[build=*]
#
# Package cytoolz conflicts for:
# scikit-image -> cytoolz[version='>=0.7.3']
# ibm-wsrt-py37main-main -> cytoolz==0.10.1[build=*]
# cytoolz
#
# Package typing conflicts for:
# pytorch -> typing
# typing_extensions -> typing[version='>=3.7.4']
#
# Package readline conflicts for:
# readline
# libpq -> readline[version='>=7.0,<8.0a0|>=8.0,<9.0a0']
# sqlite -> readline[version='>=8.0,<9.0a0']
# freetds -> readline[version='>=7.0,<8.0a0|>=8.0,<9.0a0']
# python=3.7 -> readline[version='>=7.0,<8.0a0|>=8.0,<9.0a0']
# ibm-wsrt-py37main-main -> readline==8.0[build=*]
#
# Package pywavelets conflicts for:
# pywavelets
# scikit-image -> pywavelets[version='>=0.4.0']
# ibm-wsrt-py37main-main -> pywavelets==1.1.1[build=*]
#
# Package cx_oracle conflicts for:
# ibm-wsrt-py37main-main -> cx_oracle==7.2.3[build=*]
# cx_oracle
# ibm-wsrt-py37main-keep -> cx_oracle=[build=*]
#
# Package yarl conflicts for:
# yarl
# ibm-wsrt-py37main-main -> yarl==1.5.1[build=*]
# aiohttp -> yarl[version='>=0.11|>=1.0,<1.6.0|>=1.0,<2.0|>=1.0,<2']
#
# Package send2trash conflicts for:
# ibm-wsrt-py37main-main -> send2trash==1.5.0[build=*]
# notebook -> send2trash[version='>=1.5.0']
# send2trash
#
# Package libffi conflicts for:
# libffi
# cffi -> libffi[version='>=3.2.1,<3.3a0|>=3.2.1,<4.0a0|>=3.3,<3.4.0a0']
# ibm-wsrt-py37main-main -> libffi==3.3[build=*]
# gstreamer -> libffi[version='>=3.2.1,<3.3a0|>=3.2.1,<4.0a0']
# python=3.7 -> libffi[version='>=3.2.1,<3.3a0|>=3.2.1,<4.0a0|>=3.3,<3.4.0a0']
#
# Package gst-plugins-base conflicts for:
# gst-plugins-base
# ibm-wsrt-py37main-main -> gst-plugins-base==1.14.0[build=*]
# qt -> gst-plugins-base[version='>=1.12.2,<1.13.0a0|>=1.12.4,<1.13.0a0|>=1.14.0,<1.15.0a0']
#
# Package mpmath conflicts for:
# ibm-wsrt-py37main-main -> mpmath==1.1.0[build=*]
# mpmath
# sympy -> mpmath[version='>=0.19']
#
# Package libopenblas conflicts for:
# numexpr -> libopenblas[version='>=0.2.20,<0.2.21.0a0|>=0.3.2,<0.3.3.0a0|>=0.3.3,<1.0a0']
# scikit-learn -> libopenblas[version='>=0.2.20,<0.2.21.0a0|>=0.3.3,<1.0a0']
# scipy -> libopenblas[version='>=0.2.20,<0.2.21.0a0|>=0.3.2,<0.3.3.0a0|>=0.3.3,<1.0a0']
# numpy-base -> libopenblas[version='>=0.2.20,<0.2.21.0a0|>=0.3.2,<0.3.3.0a0|>=0.3.3,<1.0a0']
# numpy -> libopenblas[version='>=0.2.20,<0.2.21.0a0|>=0.3.2,<0.3.3.0a0|>=0.3.3,<1.0a0']
#
# Package networkx conflicts for:
# networkx
# ibm-wsrt-py37main-main -> networkx==2.4[build=*]
# scikit-image -> networkx[version='>=1.8,<2.0|>=1.8|>=2.0']
#
# Package intel-openmp conflicts for:
# ibm-wsrt-py37main-main -> intel-openmp==2020.1[build=*]
# mkl -> intel-openmp=2021
# intel-openmp
#
# Package decorator conflicts for:
# ipython -> decorator
# decorator
# networkx -> decorator[version='>=3.4.0|>=4.1.0|>=4.3.0|>=4.3.0,<5']
# ibm-wsrt-py37main-main -> decorator==4.4.2[build=*]
# traitlets -> decorator
# plotly -> decorator[version='>=4.0.6']
#
# Package pytables conflicts for:
# ibm-wsrt-py37main-main -> pytables==3.6.1[build=*]
# ibm-wsrt-py37main-keep -> pytables=[build=*]
# pytables
#
# Package _py-xgboost-mutex conflicts for:
# py-xgboost -> _py-xgboost-mutex[version='1.0|2.0',build='cpu_0|gpu_0']
# ibm-wsrt-py37main-main -> _py-xgboost-mutex==2.0=cpu_0
# _py-xgboost-mutex
#
# Package jedi conflicts for:
# jedi
# ibm-wsrt-py37main-main -> jedi==0.17.1[build=*]
# ipython -> jedi[version='>=0.10|>=0.10,<0.18']
#
# Package h5py conflicts for:
# tensorflow-base -> h5py[version='>=2.10.0,<2.11.0a0|>=3.1.0']
# h5py
# ibm-wsrt-py37main-main -> h5py==2.10.0[build=*]
# keras-applications -> h5py
#
# Package docutils conflicts for:
# ibm-wsrt-py37main-main -> docutils==0.15.2[build=*]
# botocore -> docutils[version='>=0.10|>=0.10,<0.15|>=0.10,<0.16']
# docutils
#
# Package jeepney conflicts for:
# ibm-wsrt-py37main-main -> jeepney==0.4.0[build=*]
# keyring -> jeepney[version='>=0.4.2']
# secretstorage -> jeepney[version='>=0.6']
# jeepney
#
# Package certifi conflicts for:
# tornado -> certifi
# certifi
# matplotlib-base -> certifi[version='>=2020.06.20']
# ibm-wsrt-py37main-main -> certifi==2021.5.30[build=*]
# setuptools -> certifi[version='>=2016.09|>=2016.9.26']
# requests -> certifi[version='>=2017.4.17']
# urllib3 -> certifi
#
# Package locket conflicts for:
# partd -> locket
# locket
#
# Package pluggy conflicts for:
# ibm-wsrt-py37main-main -> pluggy==0.13.1[build=*]
# pytest -> pluggy[version='>=0.12,<1.0.0a1|>=0.12,<1.0|>=0.9,!=0.10,<1.0|>=0.9|>=0.7|>=0.5,<0.7']
# pluggy
#
# Package pysocks conflicts for:
# urllib3 -> pysocks[version='>=1.5.6,<2.0,!=1.5.7']
# pysocks
# ibm-wsrt-py37main-main -> pysocks==1.7.1[build=*]
#
# Package ipaddress conflicts for:
# urllib3 -> ipaddress
# notebook -> ipaddress
# cryptography -> ipaddress
#
# Package tabulate conflicts for:
# tabulate
# ibm-wsrt-py37main-main -> tabulate==0.8.3[build=*]
# ibm-wsrt-py37main-keep -> tabulate=[build=*]
#
# Package soupsieve conflicts for:
# beautifulsoup4 -> soupsieve[version='>=1.2']
# ibm-wsrt-py37main-main -> soupsieve==2.0.1[build=*]
# soupsieve
#
# Package gmpy2 conflicts for:
# sympy -> gmpy2[version='>=2.0.8']
# gmpy2
#
# Package multidict conflicts for:
# multidict
# ibm-wsrt-py37main-main -> multidict==4.7.6[build=*]
# yarl -> multidict[version='>=2.0|>=4.0']
# aiohttp -> multidict[version='>=2.1.4|>=3.0.0|>=4.0,<5.0|>=4.5,<5.0|>=4.5,<7.0']
#
# Package wrapt conflicts for:
# tensorflow-estimator -> wrapt[version='>=1.11.1']
# tensorflow-base -> wrapt[version='>=1.11.1|>=1.11.2,<2.0a0|>=1.11.2|>=1.12.1']
# ibm-wsrt-py37main-main -> wrapt==1.12.1[build=*]
# wrapt
#
# Package jinja2 conflicts for:
# nbconvert -> jinja2[version='>=2.4']
# ibm-wsrt-py37main-main -> jinja2==2.11.3[build=*]
# jupyterlab -> jinja2[version='>=2.10']
# notebook -> jinja2
# bokeh -> jinja2[version='>=2.7|>=2.9']
# jinja2
# jupyterlab_server -> jinja2[version='>2.10*|>=2.10']
#
# Package libprotobuf conflicts for:
# protobuf -> libprotobuf[version='3.10.1.*|3.11.2.*|3.11.3.*|3.11.4.*|3.12.3.*|3.12.4.*|3.13.0.*|3.13.0.1.*|>=3.13.0.1,<3.14.0a0|>=3.13.0,<3.14.0a0|>=3.12.4,<3.13.0a0|>=3.12.3,<3.13.0a0|>=3.11.4,<3.12.0a0|>=3.11.3,<3.12.0a0|>=3.11.2,<3.12.0a0|>=3.10.1,<3.11.0a0|3.9.2.*|>=3.9.2,<3.10.0a0|3.8.0.*|>=3.8.0,<3.9.0a0|>=3.7.1,<3.8.0a0|>=3.6.1,<3.6.2.0a0|>=3.6.0,<3.6.1.0a0|>=3.5.2,<3.6.0a0|>=3.5.1,<3.6.0a0|>=3.4.1,<3.5.0a0|3.14.0.*|>=3.14.0,<3.15.0a0']
# libprotobuf
# tensorflow-base -> libprotobuf[version='>=3.14.0,<3.15.0a0']
# ibm-wsrt-py37main-main -> libprotobuf==3.12.3[build=*]
#
# Package keras-applications conflicts for:
# keras-applications
# tensorflow-base -> keras-applications[version='>=1.0.5|>=1.0.6|>=1.0.8|>=1.0.8,<2.0a0']
# ibm-wsrt-py37main-main -> keras-applications==1.0.8[build=*]
#
# Package snowballstemmer conflicts for:
# snowballstemmer
# ibm-wsrt-py37main-main -> snowballstemmer==2.0.0[build=*]
# ibm-wsrt-py37main-keep -> snowballstemmer=[build=*]
#
# Package lzo conflicts for:
# ibm-wsrt-py37main-main -> lzo==2.10[build=*]
# lzo
# pytables -> lzo[version='2.*|>=2.10,<3.0a0']
#
# Package libpq conflicts for:
# psycopg2 -> libpq[version='>=10.3,<11.0a0|>=11.1,<12.0a0|>=11.2,<12.0a0|>=12.2,<13.0a0|>=9.6.6']
# ibm-wsrt-py37main-main -> libpq==12.2[build=*]
# libpq
#
# Package unixodbc conflicts for:
# unixodbc
# pyodbc -> unixodbc[version='2.3.4.*|>=2.3.6,<2.4.0a0|>=2.3.7,<2.4.0a0|>=2.3.9,<2.4.0a0']
# ibm-wsrt-py37main-main -> unixodbc==2.3.7[build=*]
# freetds -> unixodbc[version='>=2.3.5,<2.4.0a0|>=2.3.6,<2.4.0a0|>=2.3.7,<2.4.0a0|>=2.3.9,<2.4.0a0']
#
# Package tqdm conflicts for:
# tqdm
# ibm-wsrt-py37main-main -> tqdm==4.47.0[build=*]
# nltk -> tqdm
#
# Package widgetsnbextension conflicts for:
# widgetsnbextension
# ibm-wsrt-py37main-main -> widgetsnbextension==3.5.1[build=*]
# ipywidgets -> widgetsnbextension[version='>=3.0.0|>=3.1.0,<4.0|>=3.2.0,<4.0.0|>=3.3.0,<3.4.0|>=3.4.0,<3.5.0|>=3.5.0,<3.6.0']
# arcgis -> widgetsnbextension[version='>=3']
#
# Package krb5 conflicts for:
# krb5
# libpq -> krb5[version='>=1.14.2,<1.15.0a0|>=1.16,<1.17.0a0|>=1.16.1,<1.17.0a0|>=1.17.1,<1.18.0a0']
# freetds -> krb5[version='>=1.18.2,<1.19.0a0|>=1.19.1,<1.20.0a0']
# ibm-wsrt-py37main-main -> krb5==1.17.1[build=*]
#
# Package pyerfa conflicts for:
# pyerfa
# astropy -> pyerfa
#
# Package bzip2 conflicts for:
# bzip2
# pytables -> bzip2[version='>=1.0.6,<2.0a0|>=1.0.8,<2.0a0']
# ibm-wsrt-py37main-main -> bzip2==1.0.8[build=*]
#
# Package libgfortran4 conflicts for:
# libgfortran4
# libgfortran-ng -> libgfortran4=7.5.0
#
# Package zstd conflicts for:
# blosc -> zstd[version='>=1.3.7,<1.3.8.0a0|>=1.4.4,<1.4.5.0a0|>=1.4.5,<1.4.6.0a0|>=1.4.5,<1.5.0a0|>=1.4.4,<1.5.0a0']
# zstd
# ibm-wsrt-py37main-main -> zstd==1.4.5[build=*]
# libtiff -> zstd[version='>=1.3.7,<1.3.8.0a0|>=1.4|>=1.4.4,<1.4.5.0a0|>=1.4.5,<1.5.0a0|>=1.4.4,<1.5.0a0']
#
# Package patsy conflicts for:
# seaborn -> patsy
# patsy
# ibm-wsrt-py37main-main -> patsy==0.5.1[build=*]
# statsmodels -> patsy[version='>=0.4.0|>=0.5.1']
#
# Package ibm-wsrt-py37main-keep conflicts for:
# ibm-wsrt-py37main-keep
# ibm-wsrt-py37main-main -> ibm-wsrt-py37main-keep
#
# Package tensorboard conflicts for:
# ibm-wsrt-py37main-main -> tensorboard==2.1.0[build=*]
# ibm-wsrt-py37main-keep -> tensorboard=[build=*]
# tensorboard
# tensorflow-base -> tensorboard[version='>=2.5.0,<2.6']
#
# Package toml conflicts for:
# pytest -> toml
# toml
#
# Package google-pasta conflicts for:
# google-pasta
# ibm-wsrt-py37main-main -> google-pasta==0.2.0[build=*]
# tensorflow-base -> google-pasta[version='>=0.1.6|>=0.1.7,<1.0a0|>=0.1.7|>=0.1.8|>=0.2|>=0.2.0']
#
# Package partd conflicts for:
# dask-core -> partd[version='>=0.3.10']
# partd
#
# Package coverage conflicts for:
# grpcio -> coverage
# coverage
#
# Package urllib3 conflicts for:
# requests -> urllib3[version='>=1.21.1,<1.23|>=1.21.1,<1.24|>=1.21.1,<1.25|>=1.21.1,<1.26,!=1.25.0,!=1.25.1|>=1.21.1,<1.27']
# botocore -> urllib3[version='>=1.20,<1.24|>=1.20,<1.25|>=1.20,<1.26|>=1.25.4,<1.27']
# ibm-wsrt-py37main-main -> urllib3==1.25.9[build=*]
# urllib3
#
# Package requests-oauthlib conflicts for:
# google-auth-oauthlib -> requests-oauthlib[version='>=0.7.0']
# ibm-wsrt-py37main-main -> requests-oauthlib==1.3.0[build=*]
# requests-oauthlib
#
# Package ninja conflicts for:
# pytorch -> ninja
# ibm-wsrt-py37main-main -> ninja==1.9.0[build=*]
# ninja
#
# Package jupyter_client conflicts for:
# ibm-wsrt-py37main-main -> jupyter_client==6.1.3[build=*]
# nbconvert -> jupyter_client[version='>=4.2']
# notebook -> jupyter_client[version='>=5.2.0|>=5.3.1|>=5.3.4']
# nbclient -> jupyter_client[version='>=6.1.5']
# jupyter_client
# ipykernel -> jupyter_client
#
# Package wheel conflicts for:
# pip -> wheel
# ibm-wsrt-py37main-main -> wheel==0.34.2[build=*]
# tensorboard -> wheel[version='>=0.26']
# wheel
# tensorflow-base -> wheel[version='<0.36|>=0.35,<0.36']
#
# Package __glibc conflicts for:
# @/linux-64::__glibc==2.28=0
# libstdcxx-ng -> __glibc[version='>=2.17']
# @|@/linux-64::__glibc==2.28=0
# libgcc-ng -> __glibc[version='>=2.17']
# libgfortran-ng -> __glibc[version='>=2.17']
#
# Package keras-preprocessing conflicts for:
# keras-preprocessing
# ibm-wsrt-py37main-main -> keras-preprocessing==1.1.0[build=*]
# tensorflow-base -> keras-preprocessing[version='>=1.0.3|>=1.0.5|>=1.0.5,<2.0a0|>=1.1.0|>=1.1.2']
#
# Package xlsxwriter conflicts for:
# xlsxwriter
# ibm-wsrt-py37main-main -> xlsxwriter==1.2.9[build=*]
# ibm-wsrt-py37main-keep -> xlsxwriter=[build=*]
#
# Package scikit-image conflicts for:
# ibm-wsrt-py37main-main -> scikit-image==0.16.2[build=*]
# scikit-image
# ibm-wsrt-py37main-keep -> scikit-image=[build=*]
#
# Package pymssql conflicts for:
# ibm-wsrt-py37main-keep -> pymssql=[build=*]
# pymssql
# ibm-wsrt-py37main-main -> pymssql==2.1.5[build=*]
#
# Package olefile conflicts for:
# olefile
# ibm-wsrt-py37main-main -> olefile==0.46[build=*]
# pillow -> olefile
#
# Package cython conflicts for:
# cython
# grpcio -> cython
#
# Package retrying conflicts for:
# ibm-wsrt-py37main-main -> retrying==1.3.3[build=*]
# retrying
# plotly -> retrying[version='>=1.3.3']
#
# Package enum34 conflicts for:
# imageio -> enum34
# grpcio -> enum34[version='>=1.0.4']
# traitlets -> enum34
# tensorflow-base -> enum34[version='>=1.1.6|>=1.1.6,<2.0a0']
# cryptography -> enum34
# absl-py -> enum34
#
# Package singledispatch conflicts for:
# tornado -> singledispatch
# nltk -> singledispatch
#
# Package ca-certificates conflicts for:
# ca-certificates
# openssl -> ca-certificates
# ibm-wsrt-py37main-main -> ca-certificates==2021.5.25[build=*]
#
# Package functools32 conflicts for:
# jsonschema -> functools32
# matplotlib -> functools32
# tensorflow-base -> functools32[version='>=3.2.3.2']
#
# Package cudnn conflicts for:
# tensorflow-base -> cudnn[version='7.*|7.0.*|7.1.*|7.2.*|>=7.3.1,<8.0a0|>=7.6,<8.0a0|>=7.6.5,<8.0a0|>=7.6.0,<8.0a0|>=7.6.4,<8.0a0|>=7.2.0,<=8.0a0|>=7.1.0,<=8.0a0|>=7.0.0,<=8.0a0|>=7.1.2,<=8.0a0|>=7.0.5,<=8.0a0']
# pytorch -> cudnn[version='5.1.*|6.0.*|7.*|7.1.*|7.3.*|>=7.6,<8.0a0|>=7.6.5,<8.0a0|>=7.6.4,<8.0a0|>=7.3.1,<8.0a0|>=7.1.3,<8.0a0|7.0.*|>=7.3.0,<=8.0a0|>=7.1.0,<=8.0a0|>=7.1.2,<=8.0a0|>=7.0.5,<=8.0a0|>=7.0.0,<=8.0a0']
#
# Package future conflicts for:
# ibm-wsrt-py37main-main -> future==0.18.2[build=*]
# pytorch -> future
# future
# tensorflow-base -> future
# ibm-wsrt-py37main-keep -> future=[build=*]
#
# Package sympy conflicts for:
# sympy
# ibm-wsrt-py37main-keep -> sympy=[build=*]
# ibm-wsrt-py37main-main -> sympy==1.6.2=py37_0
#
# Package blinker conflicts for:
# ibm-wsrt-py37main-main -> blinker==1.4[build=*]
# oauthlib -> blinker[version='>=1.4.0']
# blinker
#
# Package parso conflicts for:
# parso
# ibm-wsrt-py37main-main -> parso==0.7.0[build=*]
# jedi -> parso[version='0.1.0|>=0.1.0,<0.2|>=0.2.0|>=0.3.0|>=0.5.0|>=0.5.2|>=0.7.0|>=0.7.0,<0.8.0|>=0.8.0,<0.9.0']
#
# Package json5 conflicts for:
# ibm-wsrt-py37main-main -> json5==0.9.5[build=*]
# jupyterlab_server -> json5
# json5
#
# Package funcsigs conflicts for:
# mock -> funcsigs
# pytest -> funcsigs[version='>=1.0']
#
# Package nbconvert conflicts for:
# notebook -> nbconvert[version='<6.0']
# nbconvert
# ibm-wsrt-py37main-main -> nbconvert==5.6.1[build=*]
#
# Package dill conflicts for:
# ibm-wsrt-py37main-main -> dill==0.3.0[build=*]
# dill
# ibm-wsrt-py37main-keep -> dill=[build=*]
#
# Package jupyterlab_server conflicts for:
# jupyterlab -> jupyterlab_server[version='>=0.2.0,<0.3.0|>=1.0.0,<2.0.0|>=1.1.0,<2.0.0|>=2.3,<3|>=1.1.5,<2.0.0']
# ibm-wsrt-py37main-main -> jupyterlab_server==1.1.0[build=*]
# jupyterlab_server
#
# Package lcms2 conflicts for:
# lcms2
# pillow -> lcms2[version='>=2.11,<3.0a0']
# ibm-wsrt-py37main-main -> lcms2==2.11[build=*]
#
# Package libgomp conflicts for:
# _openmp_mutex -> libgomp[version='>=7.5.0']
# libgomp
#
# Package subprocess32 conflicts for:
# jupyterlab -> subprocess32
# matplotlib -> subprocess32
#
# Package configparser conflicts for:
# importlib_metadata -> configparser[version='>=3.5']
# entrypoints -> configparser
#
# Package argon2-cffi conflicts for:
# argon2-cffi
# notebook -> argon2-cffi
#
# Package astunparse conflicts for:
# astunparse
# tensorflow-base -> astunparse[version='>=1.6.3|>=1.6.3,<1.6.4.0a0']
# Note that strict channel priority may have removed packages required for satisfiability.

# %%
import seaborn as sns

bins = np.linspace(df.Principal.min(), df.Principal.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'Principal', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %%
bins = np.linspace(df.age.min(), df.age.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'age', bins=bins, ec="k")

g.axes[-1].legend()
plt.show()

# %%
df['dayofweek'] = df['effective_date'].dt.dayofweek
bins=np.linspace(df.dayofweek.min(), df.dayofweek.max(), 10)
g = sns.FacetGrid(df, col="Gender", hue="loan_status", palette="Set1", col_wrap=2)
g.map(plt.hist, 'dayofweek', bins=bins, ec="k")
g.axes[-1].legend()
plt.show()

# %%
df['weekend'] = df['dayofweek'].apply(lambda x: 1 if (x>3)  else 0)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender  dayofweek  weekend
# 0 2016-10-07   45  High School or Below    male          3        0
# 1 2016-10-07   33              Bechalor  female          3        0
# 2 2016-09-22   27               college    male          3        0
# 3 2016-10-08   28               college  female          4        1
# 4 2016-10-08   29               college    male          4        1

# %%
#Convert Categorical features to numerical values
df.groupby(['Gender'])['loan_status'].value_counts(normalize=True)
# Out:
# Gender  loan_status
# female  PAIDOFF        0.865385
#         COLLECTION     0.134615
# male    PAIDOFF        0.731293
#         COLLECTION     0.268707
# Name: loan_status, dtype: float64

# %%
df['Gender'].replace(to_replace=['male','female'], value=[0,1],inplace=True)
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           0             0     PAIDOFF       1000     30     2016-09-08
# 1           2             2     PAIDOFF       1000     30     2016-09-08
# 2           3             3     PAIDOFF       1000     15     2016-09-08
# 3           4             4     PAIDOFF       1000     30     2016-09-09
# 4           6             6     PAIDOFF       1000     30     2016-09-09
#
#     due_date  age             education  Gender  dayofweek  weekend
# 0 2016-10-07   45  High School or Below       0          3        0
# 1 2016-10-07   33              Bechalor       1          3        0
# 2 2016-09-22   27               college       0          3        0
# 3 2016-10-08   28               college       1          4        1
# 4 2016-10-08   29               college       0          4        1

# %%
df.groupby(['education'])['loan_status'].value_counts(normalize=True)
# Out:
# education             loan_status
# Bechalor              PAIDOFF        0.750000
#                       COLLECTION     0.250000
# High School or Below  PAIDOFF        0.741722
#                       COLLECTION     0.258278
# Master or Above       COLLECTION     0.500000
#                       PAIDOFF        0.500000
# college               PAIDOFF        0.765101
#                       COLLECTION     0.234899
# Name: loan_status, dtype: float64

# %%
df[['Principal','terms','age','Gender','education']].head()
# Out:
#    Principal  terms  age  Gender             education
# 0       1000     30   45       0  High School or Below
# 1       1000     30   33       1              Bechalor
# 2       1000     15   27       0               college
# 3       1000     30   28       1               college
# 4       1000     30   29       0               college

# %%
Feature = df[['Principal','terms','age','Gender','weekend']]
Feature = pd.concat([Feature,pd.get_dummies(df['education'])], axis=1)
Feature.drop(['Master or Above'], axis = 1,inplace=True)
Feature.head()
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   45       0        0         0                     1
# 1       1000     30   33       1        0         1                     0
# 2       1000     15   27       0        0         0                     0
# 3       1000     30   28       1        1         0                     0
# 4       1000     30   29       0        1         0                     0
#
#    college
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1

# %%
#Feature selection
X = Feature
X[0:5]
# Out:
#    Principal  terms  age  Gender  weekend  Bechalor  High School or Below  \
# 0       1000     30   45       0        0         0                     1
# 1       1000     30   33       1        0         1                     0
# 2       1000     15   27       0        0         0                     0
# 3       1000     30   28       1        1         0                     0
# 4       1000     30   29       0        1         0                     0
#
#    college
# 0        0
# 1        0
# 2        1
# 3        1
# 4        1

# %%
y = df['loan_status'].values
y[0:5]
# Out:
# array(['PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF'],
#       dtype=object)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Normalize Data


X= preprocessing.StandardScaler().fit(X).transform(X)
X[0:5]
# Out:
# array([[ 0.51578458,  0.92071769,  2.33152555, -0.42056004, -1.20577805,
#         -0.38170062,  1.13639374, -0.86968108],
#        [ 0.51578458,  0.92071769,  0.34170148,  2.37778177, -1.20577805,
#          2.61985426, -0.87997669, -0.86968108],
#        [ 0.51578458, -0.95911111, -0.65321055, -0.42056004, -1.20577805,
#         -0.38170062, -0.87997669,  1.14984679],
#        [ 0.51578458,  0.92071769, -0.48739188,  2.37778177,  0.82934003,
#         -0.38170062, -0.87997669,  1.14984679],
#        [ 0.51578458,  0.92071769, -0.3215732 , -0.42056004,  0.82934003,
#         -0.38170062, -0.87997669,  1.14984679]])

# %%
# We split the X into train and test to find the best k
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (276, 8) (276,)
# Test set: (70, 8) (70,)

# %%
# !pip uninstall sklearn --yes
# !pip uninstall scikit-learn --yes
# Out:
# Found existing installation: sklearn 0.0
# Uninstalling sklearn-0.0:
#   Successfully uninstalled sklearn-0.0
# Found existing installation: scikit-learn 0.22.1
# Uninstalling scikit-learn-0.22.1:
#   Successfully uninstalled scikit-learn-0.22.1

# %%
# We split the X into train and test to find the best k
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (276, 8) (276,)
# Test set: (70, 8) (70,)

# %%
# !pip install sklearn 
# !pip install scikit-learn
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0-py2.py3-none-any.whl
# Requirement already satisfied: scikit-learn in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from sklearn) (0.22)
# Requirement already satisfied: numpy>=1.11.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.19.2)
# Requirement already satisfied: scipy>=0.17.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.6.2)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scikit-learn->sklearn) (1.0.1)
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0
# Requirement already satisfied: scikit-learn in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.22)
# Requirement already satisfied: numpy>=1.11.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scikit-learn) (1.19.2)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied: scipy>=0.17.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scikit-learn) (1.6.2)

# %%
# We split the X into train and test to find the best k
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=4)
print ('Train set:', X_train.shape,  y_train.shape)
print ('Test set:', X_test.shape,  y_test.shape)
# Out:
# Train set: (276, 8) (276,)
# Test set: (70, 8) (70,)

# %%
# !pip install scikit-learn==0.22.1
#K Nearest Neighbor(KNN)
from sklearn.neighbors import KNeighborsClassifier
k = 3
#Train Model and Predict  
kNN_model = KNeighborsClassifier(n_neighbors=k).fit(X_train,y_train)
kNN_model
# Out:
# Collecting scikit-learn==0.22.1
#   Downloading scikit_learn-0.22.1-cp37-cp37m-manylinux1_x86_64.whl (7.0 MB)
#      |████████████████████████████████| 7.0 MB 10.1 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.11.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scikit-learn==0.22.1) (1.19.2)
# Requirement already satisfied: scipy>=0.17.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scikit-learn==0.22.1) (1.6.2)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scikit-learn==0.22.1) (1.0.1)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.22
#     Uninstalling scikit-learn-0.22:
#       Successfully uninstalled scikit-learn-0.22
# Successfully installed scikit-learn-0.22.1
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
yhat = kNN_model.predict(X_test)
yhat[0:5]
# Out:
# array(['PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF'],
#       dtype=object)

# %%
# Best k
Ks=15
mean_acc=np.zeros((Ks-1))
std_acc=np.zeros((Ks-1))
ConfustionMx=[];
for n in range(1,Ks):
    
    #Train Model and Predict  
    kNN_model = KNeighborsClassifier(n_neighbors=n).fit(X_train,y_train)
    yhat = kNN_model.predict(X_test)
    
    
    mean_acc[n-1]=np.mean(yhat==y_test);
    
    std_acc[n-1]=np.std(yhat==y_test)/np.sqrt(yhat.shape[0])
mean_acc
# Out:
# array([0.67142857, 0.65714286, 0.71428571, 0.68571429, 0.75714286,
#        0.71428571, 0.78571429, 0.75714286, 0.75714286, 0.67142857,
#        0.7       , 0.72857143, 0.7       , 0.7       ])

# %%
# Building the model again, using k=7
from sklearn.neighbors import KNeighborsClassifier
k = 7
#Train Model and Predict  
kNN_model = KNeighborsClassifier(n_neighbors=k).fit(X_train,y_train)
kNN_model
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=7, p=2,
#                      weights='uniform')

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier
DT_model = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
DT_model.fit(X_train,y_train)
DT_model
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-34-9ec33d3fab32> in <module>
#       1 #Decision Tree
# ----> 2 from sklearn.tree import DecisionTreeClassifier
#       3 DT_model = DecisionTreeClassifier(criterion="entropy", max_depth = 4)
#       4 DT_model.fit(X_train,y_train)
#       5 DT_model
#
# ModuleNotFoundError: No module named 'sklearn.tree'

# %%
yhat = DT_model.predict(X_test)
yhat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-c8afba950aa2> in <module>
# ----> 1 yhat = DT_model.predict(X_test)
#       2 yhat
#
# NameError: name 'DT_model' is not defined

# %%
#Support Vector Machine
from sklearn import svm
SVM_model = svm.SVC()
SVM_model.fit(X_train, y_train)

# %%
yhat = SVM_model.predict(X_test)
yhat

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
LR_model = LogisticRegression(C=0.01).fit(X_train,y_train)
LR_model

# %%
yhat = LR_model.predict(X_test)
yhat

# %% [markdown]
# # Model Evaluation using Test set

# %%
# !pip install scikit-learn==0.22
# !conda install scikit-learn=0.22
# Out:
# Requirement already satisfied: scikit-learn==0.22 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (0.22)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scikit-learn==0.22) (1.0.1)
# Requirement already satisfied: scipy>=0.17.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scikit-learn==0.22) (1.6.2)
# Requirement already satisfied: numpy>=1.11.0 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from scikit-learn==0.22) (1.19.2)
# Collecting package metadata (current_repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/linux-64::mkl-service==2.3.0=py37he8ac12f_0
#   - defaults/linux-64::webencodings==0.5.1=py37_1
#   - defaults/noarch::pycparser==2.20=py_2
#   - defaults/linux-64::mkl_random==1.1.1=py37h0573a6f_0
#   - defaults/linux-64::pyqt==5.9.2=py37h05f1152_2
#   - defaults/linux-64::sip==4.19.8=py37hf484d3e_0
#   - defaults/linux-64::retrying==1.3.3=py37_2
#   - defaults/linux-64::pyodbc==4.0.30=py37he6710b0_0
#   - defaults/noarch::imageio==2.9.0=pyhd3eb1b0_0
#   - defaults/noarch::pyasn1-modules==0.2.8=py_0
#   - defaults/linux-64::cycler==0.10.0=py37_0
#   - defaults/noarch::send2trash==1.5.0=pyhd3eb1b0_1
#   - defaults/linux-64::keyring==18.0.0=py37_0
#   - defaults/noarch::pyparsing==2.4.7=pyhd3eb1b0_0
#   - defaults/linux-64::entrypoints==0.3=py37_0
#   - defaults/linux-64::future==0.18.2=py37_1
#   - defaults/linux-64::libuuid==1.0.3=h1bed415_2
#   - defaults/linux-64::qt==5.9.7=h5867ecd_1
#   - defaults/linux-64::pytables==3.6.1=py37h71ec239_0
#   - defaults/linux-64::snappy==1.1.8=he6710b0_0
#   - defaults/linux-64::lxml==4.6.3=py37h9120a33_0
#   - defaults/linux-64::hdf5==1.10.4=hb1b8bf9_0
#   - defaults/linux-64::pluggy==0.13.1=py37h06a4308_0
#   - defaults/linux-64::libwebp-base==1.2.0=h27cfd23_0
#   - defaults/linux-64::krb5==1.17.1=h173b8e3_0
#   - defaults/noarch::oauthlib==3.1.0=py_0
#   - defaults/linux-64::libpng==1.6.37=hbc83047_0
#   - defaults/noarch::google-pasta==0.2.0=py_0
#   - defaults/linux-64::certifi==2021.5.30=py37h06a4308_0
#   - defaults/linux-64::libpq==12.2=h20c2e04_0
#   - defaults/noarch::html5lib==1.1=py_0
#   - defaults/linux-64::libtiff==4.2.0=h85742a9_0
#   - defaults/linux-64::tk==8.6.10=hbc83047_0
#   - defaults/linux-64::pymssql==2.1.5=py37h7b6447c_0
#   - defaults/noarch::pyshp==2.1.0=py_0
#   - defaults/linux-64::pyjwt==1.7.1=py37_0
#   - defaults/linux-64::jpeg==9b=h024ee3a_2
#   - defaults/linux-64::bzip2==1.0.8=h7b6447c_0
#   - defaults/noarch::python-dateutil==2.8.1=pyhd3eb1b0_0
#   - defaults/linux-64::mistune==0.8.4=py37h14c3975_1001
#   - defaults/linux-64::blinker==1.4=py37h06a4308_0
#   - defaults/noarch::ipython_genutils==0.2.0=pyhd3eb1b0_1
#   - defaults/linux-64::cryptography==3.4.7=py37hd23ed53_0
#   - defaults/linux-64::lzo==2.10=h7b6447c_2
#   - defaults/linux-64::h5py==2.10.0=py37h7918eee_0
#   - defaults/noarch::jsonschema==3.2.0=py_2
#   - defaults/linux-64::pysocks==1.7.1=py37_1
#   - defaults/linux-64::wrapt==1.12.1=py37h7b6447c_1
#   - defaults/linux-64::ncurses==6.2=he6710b0_1
#   - defaults/linux-64::pywavelets==1.1.1=py37h7b6447c_2
#   - esri/linux-64::arcgis==1.6.0=py37h39e3cac_1
#   - defaults/noarch::jupyterlab==2.2.6=pyhd3eb1b0_1
#   - defaults/noarch::requests-oauthlib==1.3.0=py_0
#   - defaults/linux-64::yaml==0.2.5=h7b6447c_0
#   - defaults/linux-64::libxcb==1.14=h7b6447c_0
#   - defaults/linux-64::openssl==1.1.1k=h27cfd23_0
#   - defaults/linux-64::icu==58.2=he6710b0_3
#   - defaults/linux-64::patsy==0.5.1=py37_0
#   - defaults/linux-64::brotlipy==0.7.0=py37h27cfd23_1003
#   - defaults/linux-64::libxslt==1.1.34=hc22bd24_0
#   - defaults/noarch::keras-applications==1.0.8=py_1
#   - defaults/linux-64::olefile==0.46=py37_0
#   - defaults/noarch::pyasn1==0.4.8=py_0
#   - defaults/linux-64::widgetsnbextension==3.5.1=py37_0
#   - defaults/noarch::pexpect==4.8.0=pyhd3eb1b0_3
#   - defaults/linux-64::zlib==1.2.11=h7b6447c_3
#   - defaults/noarch::threadpoolctl==2.1.0=pyh5ca1d4c_0
#   - defaults/linux-64::libffi==3.3=he6710b0_2
#   - defaults/linux-64::fastcache==1.1.0=py37h7b6447c_0
#   - defaults/linux-64::pyyaml==5.4.1=py37h27cfd23_1
#   - defaults/linux-64::freetds==1.00.97=h52ef933_0
#   - defaults/noarch::backcall==0.2.0=pyhd3eb1b0_0
#   - defaults/linux-64::xz==5.2.5=h7b6447c_0
#   - defaults/noarch::werkzeug==1.0.1=pyhd3eb1b0_0
#   - defaults/linux-64::chardet==3.0.4=py37h06a4308_1003
#   - defaults/linux-64::async-timeout==3.0.1=py37h06a4308_0
#   - defaults/noarch::pickleshare==0.7.5=pyhd3eb1b0_1003
#   - defaults/linux-64::libsodium==1.0.18=h7b6447c_0
#   - defaults/linux-64::termcolor==1.1.0=py37h06a4308_1
#   - defaults/linux-64::yarl==1.6.3=py37h27cfd23_0
#   - defaults/noarch::traitlets==5.0.5=pyhd3eb1b0_0
#   - defaults/linux-64::pcre==8.45=h295c915_0
#   - defaults/linux-64::mpmath==1.2.1=py37h06a4308_0
#   - defaults/linux-64::blosc==1.21.0=h8c45485_0
#   - defaults/linux-64::fontconfig==2.13.1=h6c09931_0
#   - defaults/noarch::joblib==1.0.1=pyhd3eb1b0_0
#   - defaults/noarch::iniconfig==1.1.1=pyhd3eb1b0_0
#   - defaults/linux-64::libgcc-ng==9.3.0=h5101ec6_17
#   - defaults/noarch::tensorflow-estimator==2.5.0=pyh7b7c402_0
#   - defaults/linux-64::astropy==4.2.1=py37h27cfd23_1
#   - defaults/noarch::bleach==3.3.0=pyhd3eb1b0_0
#   - defaults/noarch::xlsxwriter==1.4.3=pyhd3eb1b0_0
#   - defaults/noarch::boto3==1.17.101=pyhd3eb1b0_0
#   - defaults/linux-64::markupsafe==2.0.1=py37h27cfd23_0
#   - defaults/linux-64::scikit-image==0.18.1=py37ha9443f7_0
#   - defaults/linux-64::multidict==5.1.0=py37h27cfd23_2
#   - defaults/linux-64::sympy==1.8=py37h06a4308_0
#   - defaults/linux-64::lcms2==2.12=h3be6417_0
#   - defaults/linux-64::locket==0.2.1=py37h06a4308_1
#   - defaults/linux-64::sqlalchemy==1.4.19=py37h7f8727e_0
#   - defaults/noarch::ibm-wsrt-py37main-keep==0.0.0=2527
#   - defaults/linux-64::regex==2021.4.4=py37h27cfd23_0
#   - defaults/noarch::nltk==3.6.2=pyhd3eb1b0_0
#   - defaults/noarch::zipp==3.4.1=pyhd3eb1b0_0
#   - defaults/linux-64::psycopg2==2.8.6=py37h3c74f83_1
#   - defaults/linux-64::gst-plugins-base==1.14.0=h8213a91_2
#   - defaults/linux-64::c-ares==1.17.1=h27cfd23_0
#   - defaults/noarch::wheel==0.36.2=pyhd3eb1b0_0
#   - defaults/linux-64::aiohttp==3.7.4=py37h27cfd23_1
#   - defaults/noarch::plotly==4.14.3=pyhd3eb1b0_0
#   - defaults/linux-64::jedi==0.17.0=py37_0
#   - defaults/linux-64::statsmodels==0.12.2=py37h27cfd23_0
#   - defaults/noarch::pytz==2021.1=pyhd3eb1b0_0
#   - defaults/linux-64::cffi==1.14.5=py37h261ae71_0
#   - defaults/linux-64::libedit==3.1.20210216=h27cfd23_1
#   - defaults/noarch::fsspec==2021.6.0=pyhd3eb1b0_0
#   - defaults/noarch::jupyterlab_widgets==1.0.0=pyhd3eb1b0_1
#   - defaults/linux-64::dbus==1.13.18=hb2f20db_0
#   - defaults/noarch::jinja2==3.0.1=pyhd3eb1b0_0
#   - defaults/noarch::rsa==4.7.2=pyhd3eb1b0_1
#   - defaults/noarch::toml==0.10.2=pyhd3eb1b0_0
#   - defaults/noarch::py==1.10.0=pyhd3eb1b0_0
#   - defaults/linux-64::zstd==1.4.9=haebb681_0
#   - defaults/linux-64::importlib-metadata==3.10.0=py37h06a4308_0
#   - defaults/linux-64::libprotobuf==3.14.0=h8c45485_0
#   - defaults/linux-64::matplotlib==3.3.4=py37h06a4308_0
#   - defaults/noarch::prometheus_client==0.11.0=pyhd3eb1b0_0
#   - defaults/linux-64::python==3.7.10=h12debd9_4
#   - defaults/linux-64::biopython==1.78=py37h7b6447c_0
#   - defaults/linux-64::freetype==2.10.4=h5ab3b9f_0
#   - defaults/noarch::keras-preprocessing==1.1.2=pyhd3eb1b0_0
#   - defaults/noarch::nbformat==5.1.3=pyhd3eb1b0_0
#   - defaults/linux-64::pip==21.1.3=py37h06a4308_0
#   - defaults/linux-64::ninja==1.10.2=hff7bd54_1
#   - defaults/linux-64::mpfr==4.0.2=hb69a4c5_1
#   - defaults/linux-64::protobuf==3.14.0=py37h2531618_1
#   - defaults/noarch::jupyter_client==6.1.12=pyhd3eb1b0_0
#   - defaults/linux-64::pyerfa==2.0.0=py37h27cfd23_0
#   - defaults/linux-64::terminado==0.9.4=py37h06a4308_0
#   - defaults/noarch::jupyterlab_pygments==0.1.2=py_0
#   - defaults/linux-64::coverage==5.5=py37h27cfd23_2
#   - defaults/linux-64::gmpy2==2.0.8=py37h10f8cd9_2
#   - defaults/linux-64::astor==0.8.1=py37h06a4308_0
#   - defaults/linux-64::ipython==7.22.0=py37hb070fc8_0
#   - defaults/linux-64::ipykernel==5.3.4=py37h5ca1d4c_0
#   - defaults/noarch::tensorboard==2.4.0=pyhc547734_0
#   - defaults/noarch::prompt-toolkit==3.0.17=pyh06a4308_0
#   - defaults/linux-64::cx_oracle==8.2.1=py37h27cfd23_0
#   - defaults/noarch::importlib_metadata==3.10.0=hd3eb1b0_0
#   - defaults/noarch::mock==4.0.3=pyhd3eb1b0_0
#   - defaults/linux-64::pytorch==1.4.0=cpu_py37h7e40bad_0
#   - defaults/linux-64::gmp==6.2.1=h2531618_2
#   - defaults/noarch::snowballstemmer==2.1.0=pyhd3eb1b0_0
#   - defaults/noarch::tensorboard-plugin-wit==1.6.0=py_0
#   - defaults/noarch::jupyterlab_server==1.2.0=py_0
#   - defaults/linux-64::pillow==8.2.0=py37he98fc37_0
#   - defaults/linux-64::grpcio==1.36.1=py37h2157cd5_1
#   - defaults/noarch::click==8.0.1=pyhd3eb1b0_0
#   - defaults/noarch::ibm-wsrt-py37main-main==custom=2527
#   - defaults/noarch::dill==0.3.4=pyhd3eb1b0_0
#   - defaults/noarch::pyopenssl==20.0.1=pyhd3eb1b0_1
#   - defaults/noarch::wcwidth==0.2.5=py_0
#   - defaults/noarch::gast==0.4.0=py_0
#   - defaults/linux-64::numpy==1.19.2=py37h54aff64_0
#   - defaults/noarch::beautifulsoup4==4.9.3=pyha847dfd_0
#   - defaults/noarch::pygments==2.9.0=pyhd3eb1b0_0
#   - defaults/noarch::ptyprocess==0.7.0=pyhd3eb1b0_2
#   - defaults/noarch::networkx==2.5=py_0
#   - defaults/linux-64::pytest==6.2.4=py37h06a4308_2
#   - defaults/linux-64::pandocfilters==1.4.3=py37h06a4308_1
#   - defaults/linux-64::argon2-cffi==20.1.0=py37h27cfd23_1
#   - defaults/noarch::cachetools==4.2.2=pyhd3eb1b0_0
#   - defaults/linux-64::libstdcxx-ng==9.3.0=hd4cf53a_17
#   - defaults/noarch::decorator==5.0.9=pyhd3eb1b0_0
#   - defaults/noarch::nbclient==0.5.3=pyhd3eb1b0_0
#   - defaults/linux-64::kiwisolver==1.3.1=py37h2531618_0
#   - defaults/noarch::partd==1.2.0=pyhd3eb1b0_0
#   - defaults/linux-64::greenlet==1.1.0=py37h2531618_0
#   - defaults/noarch::astunparse==1.6.3=py_0
#   - defaults/noarch::google-auth==1.32.0=pyhd3eb1b0_0
#   - defaults/linux-64::expat==2.4.1=h2531618_2
#   - defaults/noarch::parso==0.8.2=pyhd3eb1b0_0
#   - defaults/noarch::urllib3==1.26.6=pyhd3eb1b0_1
#   - defaults/noarch::typing_extensions==3.10.0.0=pyh06a4308_0
#   - defaults/noarch::botocore==1.20.101=pyhd3eb1b0_1
#   - defaults/linux-64::setuptools==52.0.0=py37h06a4308_0
#   - defaults/linux-64::nbconvert==6.1.0=py37h06a4308_0
#   - defaults/noarch::testpath==0.5.0=pyhd3eb1b0_0
#   - defaults/linux-64::lz4-c==1.9.3=h2531618_0
#   - defaults/linux-64::tabulate==0.8.9=py37h06a4308_0
#   - defaults/linux-64::markdown==3.3.4=py37h06a4308_0
#   - defaults/linux-64::numexpr==2.7.3=py37hb2eb853_0
#   - defaults/noarch::requests==2.25.1=pyhd3eb1b0_0
#   - defaults/linux-64::unixodbc==2.3.9=h7b6447c_0
#   - defaults/linux-64::pandas==1.2.4=py37h2531618_0
#   - defaults/noarch::cloudpickle==1.6.0=py_0
#   - defaults/noarch::tqdm==4.61.2=pyhd3eb1b0_1
#   - defaults/linux-64::pyrsistent==0.17.3=py37h7b6447c_0
#   - defaults/noarch::opt_einsum==3.3.0=pyhd3eb1b0_1
#   - defaults/linux-64::sqlite==3.36.0=hc218d9a_0
#   - defaults/linux-64::readline==8.1=h27cfd23_0
#   - defaults/noarch::jeepney==0.6.0=pyhd3eb1b0_0
#   - defaults/linux-64::cytoolz==0.11.0=py37h7b6447c_0
#   - defaults/linux-64::mpc==1.1.0=h10f8cd9_1
#   - defaults/noarch::defusedxml==0.7.1=pyhd3eb1b0_0
#   - defaults/linux-64::secretstorage==3.3.1=py37h06a4308_0
#   - defaults/noarch::soupsieve==2.2.1=pyhd3eb1b0_0
#   - defaults/linux-64::gstreamer==1.14.0=h28cd5cc_2
#   - defaults/linux-64::numpy-base==1.19.2=py37hfa32c7d_0
#   - defaults/linux-64::bokeh==2.3.2=py37h06a4308_0
#   - defaults/linux-64::jupyter_core==4.7.1=py37h06a4308_0
#   - defaults/noarch::attrs==21.2.0=pyhd3eb1b0_0
#   - defaults/noarch::six==1.16.0=pyhd3eb1b0_0
#   - defaults/linux-64::tensorflow-base==2.4.1=mkl_py37h43e0292_0
#   - defaults/linux-64::scikit-learn==0.22.1=py37hd81dba3_0
#   - defaults/noarch::dask-core==2021.6.2=pyhd3eb1b0_0
#   - defaults/noarch::jmespath==0.10.0=py_0
#   - defaults/noarch::idna==2.10=pyhd3eb1b0_0
#   - defaults/linux-64::scipy==1.6.2=py37h91f5cce_0
#   - defaults/noarch::packaging==20.9=pyhd3eb1b0_0
#   - defaults/linux-64::tifffile==2020.10.1=py37hdd07704_2
#   - defaults/linux-64::matplotlib-base==3.3.4=py37h62a2d02_0
#   - defaults/linux-64::notebook==6.4.0=py37h06a4308_0
#   - defaults/noarch::ipywidgets==7.6.3=pyhd3eb1b0_1
#   - defaults/linux-64::libxml2==2.9.12=h03d6c58_0
#   - defaults/linux-64::docutils==0.17.1=py37h06a4308_1
#   - defaults/linux-64::absl-py==0.13.0=py37h06a4308_0
#   - defaults/noarch::json5==0.9.6=pyhd3eb1b0_0
#   - defaults/noarch::python-flatbuffers==1.12=pyhd3eb1b0_0
#   - defaults/linux-64::mkl_fft==1.3.0=py37h54f3939_0
#   - defaults/linux-64::glib==2.68.2=h36276a3_0
#   - defaults/noarch::seaborn==0.11.1=pyhd3eb1b0_0
#   - defaults/linux-64::async_generator==1.10=py37h28b3542_0
#   - defaults/noarch::typing-extensions==3.10.0.0=hd3eb1b0_0
#   - defaults/noarch::xlrd==2.0.1=pyhd3eb1b0_0
#   - defaults/linux-64::zeromq==4.3.4=h2531618_0
#   - defaults/linux-64::libxgboost==1.3.3=h2531618_0
#   - defaults/linux-64::pyzmq==20.0.0=py37h2531618_1
#   - defaults/noarch::google-auth-oauthlib==0.4.4=pyhd3eb1b0_0
#   - defaults/linux-64::py-xgboost==1.3.3=py37h06a4308_0
#   - defaults/noarch::toolz==0.11.1=pyhd3eb1b0_0
#   - defaults/noarch::more-itertools==8.8.0=pyhd3eb1b0_0
#   - defaults/linux-64::cython==0.29.23=py37h2531618_0
#   - defaults/noarch::s3transfer==0.4.2=pyhd3eb1b0_0
#   - defaults/linux-64::libgfortran-ng==7.5.0=ha8ba4b0_17
#   - defaults/linux-64::tornado==6.1=py37h27cfd23_0
#   - defaults/noarch::nest-asyncio==1.5.1=pyhd3eb1b0_0
# done
#
# # All requested packages already installed.

# %%
from sklearn.metrics import jaccard_similarity_score
from sklearn.metrics import f1_score
from sklearn.metrics import log_loss

# %%
# !wget -O loan_test.csv https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_test.csv
# Out:
# --2021-07-07 09:39:10--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/ML0101ENv3/labs/loan_test.csv
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3642 (3.6K) [text/csv]
# Saving to: ‘loan_test.csv’
#
# loan_test.csv       100%[===================>]   3.56K  --.-KB/s    in 0s
#
# 2021-07-07 09:39:10 (86.3 MB/s) - ‘loan_test.csv’ saved [3642/3642]

# %%
test_df = pd.read_csv('loan_test.csv')
test_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1 loan_status  Principal  terms effective_date  \
# 0           1             1     PAIDOFF       1000     30       9/8/2016
# 1           5             5     PAIDOFF        300      7       9/9/2016
# 2          21            21     PAIDOFF       1000     30      9/10/2016
# 3          24            24     PAIDOFF       1000     30      9/10/2016
# 4          35            35     PAIDOFF        800     15      9/11/2016
#
#     due_date  age             education  Gender
# 0  10/7/2016   50              Bechalor  female
# 1  9/15/2016   35       Master or Above    male
# 2  10/9/2016   43  High School or Below  female
# 3  10/9/2016   26               college    male
# 4  9/25/2016   29              Bechalor    male

# %%
## Preprocessing
test_df['due_date'] = pd.to_datetime(test_df['due_date'])
test_df['effective_date'] = pd.to_datetime(test_df['effective_date'])
test_df['dayofweek'] = test_df['effective_date'].dt.dayofweek
test_df['weekend'] = test_df['dayofweek'].apply(lambda x: 1 if (x>3)  else 0)
test_df['Gender'].replace(to_replace=['male','female'], value=[0,1],inplace=True)
test_Feature = test_df[['Principal','terms','age','Gender','weekend']]
test_Feature = pd.concat([test_Feature,pd.get_dummies(test_df['education'])], axis=1)
test_Feature.drop(['Master or Above'], axis = 1,inplace=True)
test_X = preprocessing.StandardScaler().fit(test_Feature).transform(test_Feature)
test_X[0:5]
# Out:
# array([[ 0.49362588,  0.92844966,  3.05981865,  1.97714211, -1.30384048,
#          2.39791576, -0.79772404, -0.86135677],
#        [-3.56269116, -1.70427745,  0.53336288, -0.50578054,  0.76696499,
#         -0.41702883, -0.79772404, -0.86135677],
#        [ 0.49362588,  0.92844966,  1.88080596,  1.97714211,  0.76696499,
#         -0.41702883,  1.25356634, -0.86135677],
#        [ 0.49362588,  0.92844966, -0.98251057, -0.50578054,  0.76696499,
#         -0.41702883, -0.79772404,  1.16095912],
#        [-0.66532184, -0.78854628, -0.47721942, -0.50578054,  0.76696499,
#          2.39791576, -0.79772404, -0.86135677]])

# %%
test_y = test_df['loan_status'].values
test_y[0:5]
# Out:
# array(['PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF', 'PAIDOFF'],
#       dtype=object)

# %%
knn_yhat = kNN_model.predict(test_X)
print("KNN Jaccard index: %.2f" % jaccard_similarity_score(test_y, knn_yhat))
print("KNN F1-score: %.2f" % f1_score(test_y, knn_yhat, average='weighted') )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-a130a3eb7bc2> in <module>
# ----> 1 knn_yhat = kNN_model.predict(test_X)
#       2 print("KNN Jaccard index: %.2f" % jaccard_similarity_score(test_y, knn_yhat))
#       3 print("KNN F1-score: %.2f" % f1_score(test_y, knn_yhat, average='weighted') )
#
# NameError: name 'kNN_model' is not defined
